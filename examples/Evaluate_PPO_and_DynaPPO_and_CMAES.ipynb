# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from explorers.PPO_explorer import PPO_explorer
from explorers.DynaPPO_explorer import DynaPPO_explorer
from explorers.CMAES_explorer import CMAES_explorer
from evaluators.Evaluator import Evaluator

from utils.sequence_utils import generate_random_mutant, generate_random_sequences

from models.Ground_truth_oracles.RNA_landscape_models import RNA_landscape_constructor
from models.Ground_truth_oracles.TF_binding_landscape_models import *

# %%
RNA_LANDSCAPE_TYPES = {"RNA": [0,1,12,20,25,31], "TF": []}
TF_LANDSCAPE_TYPES =  {"RNA": [], "TF": ['POU3F4_REF_R1','PAX3_G48R_R1','SIX6_REF_R1', 'VAX2_REF_R1', 'VSX1_REF_R1']}

# %%
ppo_explorer = PPO_explorer()
ppo_explorer.debug = False

num_starts = 3
print("Evaluating adaptivity.")
evaluator_ppo = Evaluator(ppo_explorer, landscape_types=RNA_LANDSCAPE_TYPES, path="../simulations/eval/RNA/")
evaluator_ppo.verbose = False
evaluator_ppo.evaluate_for_landscapes(evaluator_ppo.adaptivity, num_starts=num_starts)

print("Evaluating efficiency.")
evaluator_ppo = Evaluator(ppo_explorer, landscape_types=RNA_LANDSCAPE_TYPES, path="../simulations/eval/RNA/")
evaluator_ppo.verbose = False
evaluator_ppo.evaluate_for_landscapes(evaluator_ppo.efficiency, num_starts=num_starts)

print("Evaluating scalability.")
evaluator_ppo = Evaluator(ppo_explorer, landscape_types=RNA_LANDSCAPE_TYPES, path="../simulations/eval/RNA/")
evaluator_ppo.verbose = False
evaluator_ppo.evaluate_for_landscapes(evaluator_ppo.scalability, num_starts=num_starts)

print("Evaluating consistency.")
evaluator_ppo = Evaluator(ppo_explorer, landscape_types=RNA_LANDSCAPE_TYPES, path="../simulations/eval/RNA/")
evaluator_ppo.verbose = False
evaluator_ppo.evaluate_for_landscapes(evaluator_ppo.consistency_robustness_independence, num_starts=num_starts)
# Out:
# Evaluating adaptivity.
# loading landscapes RNA: [0, 1, 12, 20, 25, 31], TF:[]
# B1L14RNA1 loaded
# B1L50RNA1 loaded
# B2L14RNA1+2 loaded
# B2L50RNA1+4 loaded
# B2L100RNA1+3 loaded
# C20B2L100RNA1+3 loaded
# 0 TF landscapes loaded.
# loading complete
# Running on B1L14RNA1
# start seq startRNAL14_0
# Evaluating for num_batches: 1
# Episodes: 0/1000
# /Users/richard/Documents/Research/FLSD-Sandbox/models/Ground_truth_oracles/RNA_landscape_models.py:21: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   self.loaded_landscapes = yaml.load(cfgfile)
# Number of measured sequences: 176
# New top sequence: (0.8018893853389146, 'AUGGGCCGGGCGCC', 1)
# Proposing samples...
# Evaluating for num_batches: 10
# Episodes: 0/1000
# Number of measured sequences: 46
# New top sequence: (0.724995853216537, 'AUGGGCCGGGCUCC', 1)
# Episodes: 170/1000
# Number of measured sequences: 90
# Episodes: 329/1000
# Number of measured sequences: 146
# Episodes: 503/1000
# Number of measured sequences: 193
# Episodes: 664/1000
# Number of measured sequences: 245
# Episodes: 843/1000
# Number of measured sequences: 284
# New top sequence: (0.7469654562713052, 'AGCGGGGGGCCCAG', 1)
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Evaluating for num_batches: 100
# Episodes: 0/1000
# Number of measured sequences: 4
# Episodes: 14/1000
# Number of measured sequences: 9
# New top sequence: (0.6041632197437043, 'AUGCGCCGGCCCCC', 1)
# Episodes: 29/1000
# Number of measured sequences: 15
# New top sequence: (0.6288789773482205, 'AUGGGCCGGCGCCC', 1)
# Episodes: 48/1000
# Number of measured sequences: 20
# Episodes: 65/1000
# Number of measured sequences: 25
# New top sequence: (0.6371175981360863, 'AUGGGCCCGCCCCC', 1)
# Episodes: 81/1000
# Number of measured sequences: 31
# Episodes: 99/1000
# Number of measured sequences: 34
# New top sequence: (0.6618333557406024, 'AUGGCUCCGCCCCC', 1)
# Episodes: 115/1000
# Number of measured sequences: 42
# New top sequence: (0.6645795626698909, 'CCGCUCCGGCCCCG', 1)
# Episodes: 139/1000
# Number of measured sequences: 46
# Episodes: 154/1000
# Number of measured sequences: 54
# Episodes: 175/1000
# Number of measured sequences: 60
# Episodes: 192/1000
# Number of measured sequences: 65
# New top sequence: (0.6810566994865414, 'UGGGGCCGGCGCGU', 1)
# Episodes: 211/1000
# Number of measured sequences: 73
# Episodes: 229/1000
# Number of measured sequences: 78
# Episodes: 245/1000
# Number of measured sequences: 82
# Episodes: 260/1000
# Number of measured sequences: 85
# New top sequence: (0.7112648709496348, 'AUGGGGCCGGGCGC', 1)
# Episodes: 278/1000
# Number of measured sequences: 89
# Episodes: 292/1000
# Number of measured sequences: 94
# Episodes: 307/1000
# Number of measured sequences: 100
# Episodes: 325/1000
# Number of measured sequences: 108
# Episodes: 343/1000
# Number of measured sequences: 113
# New top sequence: (0.7909045576217604, 'CCGCGCCGGCCCCG', 1)
# Episodes: 360/1000
# Number of measured sequences: 116
# Episodes: 374/1000
# Number of measured sequences: 120
# Episodes: 389/1000
# Number of measured sequences: 128
# New top sequence: (0.7991431784096261, 'CCCGUGGGGCCCCG', 1)
# Episodes: 408/1000
# Number of measured sequences: 132
# Episodes: 422/1000
# Number of measured sequences: 135
# New top sequence: (0.867798089744138, 'CCGCGCGGGCCCCG', 1)
# Episodes: 440/1000
# Number of measured sequences: 139
# Episodes: 454/1000
# Number of measured sequences: 144
# Episodes: 470/1000
# Number of measured sequences: 151
# Episodes: 488/1000
# Number of measured sequences: 157
# Episodes: 504/1000
# Number of measured sequences: 162
# Episodes: 520/1000
# Number of measured sequences: 164
# Episodes: 532/1000
# Number of measured sequences: 168
# New top sequence: (0.8787828650817517, 'CCGCGCGGGGCCCG', 1)
# Episodes: 549/1000
# Number of measured sequences: 173
# Episodes: 567/1000
# Number of measured sequences: 177
# Episodes: 585/1000
# Number of measured sequences: 181
# Episodes: 599/1000
# Number of measured sequences: 184
# Episodes: 612/1000
# Number of measured sequences: 188
# Episodes: 627/1000
# Number of measured sequences: 194
# Episodes: 644/1000
# Number of measured sequences: 200
# Episodes: 662/1000
# Number of measured sequences: 204
# Episodes: 676/1000
# Number of measured sequences: 212
# Episodes: 696/1000
# Number of measured sequences: 215
# Episodes: 710/1000
# Number of measured sequences: 221
# Episodes: 726/1000
# Number of measured sequences: 223
# Episodes: 741/1000
# Number of measured sequences: 226
# Episodes: 755/1000
# Number of measured sequences: 230
# Episodes: 771/1000
# Number of measured sequences: 233
# Episodes: 786/1000
# Number of measured sequences: 234
# Episodes: 797/1000
# Number of measured sequences: 237
# New top sequence: (0.8925138473486541, 'CCGCGGGGGCCCCC', 1)
# Episodes: 811/1000
# Number of measured sequences: 240
# Episodes: 825/1000
# Number of measured sequences: 244
# Episodes: 840/1000
# Number of measured sequences: 247
# Episodes: 853/1000
# Number of measured sequences: 253
# Episodes: 871/1000
# Number of measured sequences: 257
# Episodes: 885/1000
# Number of measured sequences: 262
# Episodes: 900/1000
# Number of measured sequences: 266
# Episodes: 915/1000
# Number of measured sequences: 273
# Episodes: 933/1000
# Number of measured sequences: 276
# New top sequence: (0.9007524157569793, 'CCGCGGGGGGCCCG', 1)
# Episodes: 948/1000
# Number of measured sequences: 281
# Episodes: 964/1000
# Number of measured sequences: 285
# New top sequence: (0.9309606395996132, 'CCGCGUGGGGGCCG', 1)
# Episodes: 979/1000
# Number of measured sequences: 288
# Episodes: 992/1000
# Number of measured sequences: 290
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Evaluating for num_batches: 1000
# Episodes: 0/1000
# Number of measured sequences: 1
# Episodes: 1/1000
# Number of measured sequences: 2
# Episodes: 3/1000
# Number of measured sequences: 2
# Episodes: 4/1000
# Number of measured sequences: 2
# Episodes: 5/1000
# Number of measured sequences: 3
# Episodes: 7/1000
# Number of measured sequences: 3
# Episodes: 8/1000
# Number of measured sequences: 3
# Episodes: 9/1000
# Number of measured sequences: 3
# Episodes: 10/1000
# Number of measured sequences: 4
# Episodes: 12/1000
# Number of measured sequences: 4
# Episodes: 13/1000
# Number of measured sequences: 4
# Episodes: 14/1000
# Number of measured sequences: 5
# Episodes: 16/1000
# Number of measured sequences: 5
# Episodes: 17/1000
# Number of measured sequences: 5
# Episodes: 18/1000
# Number of measured sequences: 5
# Episodes: 19/1000
# Number of measured sequences: 5
# Episodes: 20/1000
# Number of measured sequences: 6
# Episodes: 23/1000
# Number of measured sequences: 6
# Episodes: 24/1000
# Number of measured sequences: 7
# Episodes: 27/1000
# Number of measured sequences: 8
# Episodes: 29/1000
# Number of measured sequences: 8
# Episodes: 30/1000
# Number of measured sequences: 8
# Episodes: 31/1000
# Number of measured sequences: 8
# Episodes: 32/1000
# Number of measured sequences: 8
# Episodes: 33/1000
# Number of measured sequences: 8
# Episodes: 34/1000
# Number of measured sequences: 8
# Episodes: 35/1000
# Number of measured sequences: 9
# Episodes: 37/1000
# Number of measured sequences: 10
# Episodes: 39/1000
# Number of measured sequences: 11
# Episodes: 41/1000
# Number of measured sequences: 12
# Episodes: 43/1000
# Number of measured sequences: 12
# Episodes: 44/1000
# Number of measured sequences: 13
# New top sequence: (0.7222496462872485, 'AGGGGGGCCGCCGC', 1)
# Episodes: 48/1000
# Number of measured sequences: 13
# Episodes: 49/1000
# Number of measured sequences: 13
# Episodes: 50/1000
# Number of measured sequences: 13
# Episodes: 51/1000
# Number of measured sequences: 13
# Episodes: 52/1000
# Number of measured sequences: 14
# Episodes: 54/1000
# Number of measured sequences: 14
# Episodes: 55/1000
# Number of measured sequences: 14
# Episodes: 56/1000
# Number of measured sequences: 14
# Episodes: 57/1000
# Number of measured sequences: 15
# Episodes: 59/1000
# Number of measured sequences: 16
# Episodes: 61/1000
# Number of measured sequences: 17
# Episodes: 63/1000
# Number of measured sequences: 17
# Episodes: 64/1000
# Number of measured sequences: 17
# Episodes: 65/1000
# Number of measured sequences: 18
# Episodes: 67/1000
# Number of measured sequences: 18
# Episodes: 68/1000
# Number of measured sequences: 19
# Episodes: 70/1000
# Number of measured sequences: 20
# Episodes: 72/1000
# Number of measured sequences: 20
# Episodes: 73/1000
# Number of measured sequences: 20
# Episodes: 74/1000
# Number of measured sequences: 20
# Episodes: 75/1000
# Number of measured sequences: 21
# New top sequence: (0.7304882670751143, 'AGGGGCCGGCCCCC', 1)
# Episodes: 77/1000
# Number of measured sequences: 22
# Episodes: 81/1000
# Number of measured sequences: 22
# Episodes: 82/1000
# Number of measured sequences: 22
# Episodes: 83/1000
# Number of measured sequences: 22
# Episodes: 84/1000
# Number of measured sequences: 22
# Episodes: 85/1000
# Number of measured sequences: 23
# Episodes: 88/1000
# Number of measured sequences: 23
# Episodes: 89/1000
# Number of measured sequences: 23
# Episodes: 90/1000
# Number of measured sequences: 23
# Episodes: 91/1000
# Number of measured sequences: 24
# Episodes: 95/1000
# Number of measured sequences: 24
# Episodes: 96/1000
# Number of measured sequences: 25
# Episodes: 98/1000
# Number of measured sequences: 25
# Episodes: 99/1000
# Number of measured sequences: 26
# Episodes: 101/1000
# Number of measured sequences: 26
# Episodes: 102/1000
# Number of measured sequences: 27
# Episodes: 104/1000
# Number of measured sequences: 27
# Episodes: 105/1000
# Number of measured sequences: 28
# Episodes: 107/1000
# Number of measured sequences: 29
# New top sequence: (0.7716812138758213, 'AGUGGGGGUCUCGC', 1)
# Episodes: 110/1000
# Number of measured sequences: 29
# Episodes: 111/1000
# Number of measured sequences: 30
# Episodes: 113/1000
# Number of measured sequences: 30
# Episodes: 114/1000
# Number of measured sequences: 30
# Episodes: 115/1000
# Number of measured sequences: 30
# Episodes: 116/1000
# Number of measured sequences: 30
# Episodes: 117/1000
# Number of measured sequences: 31
# Episodes: 119/1000
# Number of measured sequences: 32
# Episodes: 123/1000
# Number of measured sequences: 32
# Episodes: 124/1000
# Number of measured sequences: 32
# Episodes: 125/1000
# Number of measured sequences: 32
# Episodes: 126/1000
# Number of measured sequences: 33
# Episodes: 128/1000
# Number of measured sequences: 34
# Episodes: 130/1000
# Number of measured sequences: 34
# Episodes: 131/1000
# Number of measured sequences: 35
# Episodes: 134/1000
# Number of measured sequences: 35
# Episodes: 135/1000
# Number of measured sequences: 36
# Episodes: 139/1000
# Number of measured sequences: 36
# Episodes: 140/1000
# Number of measured sequences: 36
# Episodes: 143/1000
# Number of measured sequences: 36
# Episodes: 144/1000
# Number of measured sequences: 37
# Episodes: 147/1000
# Number of measured sequences: 37
# Episodes: 148/1000
# Number of measured sequences: 37
# Episodes: 149/1000
# Number of measured sequences: 38
# New top sequence: (0.887021433490077, 'GGGGUCCGGCCCUC', 1)
# Episodes: 152/1000
# Number of measured sequences: 38
# Episodes: 153/1000
# Number of measured sequences: 39
# Episodes: 155/1000
# Number of measured sequences: 39
# Episodes: 156/1000
# Number of measured sequences: 40
# Episodes: 158/1000
# Number of measured sequences: 41
# Episodes: 160/1000
# Number of measured sequences: 42
# Episodes: 162/1000
# Number of measured sequences: 42
# Episodes: 163/1000
# Number of measured sequences: 43
# Episodes: 165/1000
# Number of measured sequences: 43
# Episodes: 166/1000
# Number of measured sequences: 44
# Episodes: 168/1000
# Number of measured sequences: 44
# Episodes: 169/1000
# Number of measured sequences: 45
# Episodes: 171/1000
# Number of measured sequences: 46
# Episodes: 173/1000
# Number of measured sequences: 46
# Episodes: 174/1000
# Number of measured sequences: 46
# Episodes: 175/1000
# Number of measured sequences: 46
# Episodes: 176/1000
# Number of measured sequences: 46
# Episodes: 177/1000
# Number of measured sequences: 47
# Episodes: 180/1000
# Number of measured sequences: 48
# Episodes: 182/1000
# Number of measured sequences: 48
# Episodes: 183/1000
# Number of measured sequences: 48
# Episodes: 184/1000
# Number of measured sequences: 49
# Episodes: 186/1000
# Number of measured sequences: 50
# Episodes: 188/1000
# Number of measured sequences: 51
# Episodes: 190/1000
# Number of measured sequences: 52
# Episodes: 193/1000
# Number of measured sequences: 53
# Episodes: 195/1000
# Number of measured sequences: 53
# Episodes: 196/1000
# Number of measured sequences: 53
# Episodes: 197/1000
# Number of measured sequences: 53
# Episodes: 198/1000
# Number of measured sequences: 53
# Episodes: 199/1000
# Number of measured sequences: 53
# Episodes: 200/1000
# Number of measured sequences: 53
# Episodes: 201/1000
# Number of measured sequences: 53
# Episodes: 202/1000
# Number of measured sequences: 54
# Episodes: 204/1000
# Number of measured sequences: 54
# Episodes: 206/1000
# Number of measured sequences: 55
# Episodes: 208/1000
# Number of measured sequences: 55
# Episodes: 209/1000
# Number of measured sequences: 55
# Episodes: 210/1000
# Number of measured sequences: 56
# Episodes: 213/1000
# Number of measured sequences: 57
# Episodes: 215/1000
# Number of measured sequences: 57
# Episodes: 216/1000
# Number of measured sequences: 57
# Episodes: 217/1000
# Number of measured sequences: 58
# Episodes: 219/1000
# Number of measured sequences: 58
# Episodes: 220/1000
# Number of measured sequences: 58
# Episodes: 221/1000
# Number of measured sequences: 59
# Episodes: 223/1000
# Number of measured sequences: 59
# Episodes: 224/1000
# Number of measured sequences: 60
# Episodes: 226/1000
# Number of measured sequences: 60
# Episodes: 227/1000
# Number of measured sequences: 61
# Episodes: 229/1000
# Number of measured sequences: 61
# Episodes: 232/1000
# Number of measured sequences: 62
# Episodes: 234/1000
# Number of measured sequences: 62
# Episodes: 236/1000
# Number of measured sequences: 63
# Episodes: 238/1000
# Number of measured sequences: 63
# Episodes: 240/1000
# Number of measured sequences: 63
# Episodes: 241/1000
# Number of measured sequences: 63
# Episodes: 242/1000
# Number of measured sequences: 63
# Episodes: 243/1000
# Number of measured sequences: 63
# Episodes: 244/1000
# Number of measured sequences: 64
# Episodes: 246/1000
# Number of measured sequences: 65
# Episodes: 248/1000
# Number of measured sequences: 65
# Episodes: 249/1000
# Number of measured sequences: 65
# Episodes: 250/1000
# Number of measured sequences: 65
# Episodes: 251/1000
# Number of measured sequences: 65
# Episodes: 252/1000
# Number of measured sequences: 66
# Episodes: 255/1000
# Number of measured sequences: 67
# Episodes: 257/1000
# Number of measured sequences: 67
# Episodes: 260/1000
# Number of measured sequences: 67
# Episodes: 261/1000
# Number of measured sequences: 67
# Episodes: 262/1000
# Number of measured sequences: 67
# Episodes: 263/1000
# Number of measured sequences: 68
# Episodes: 265/1000
# Number of measured sequences: 68
# Episodes: 266/1000
# Number of measured sequences: 69
# Episodes: 268/1000
# Number of measured sequences: 69
# Episodes: 269/1000
# Number of measured sequences: 69
# Episodes: 270/1000
# Number of measured sequences: 70
# Episodes: 272/1000
# Number of measured sequences: 71
# Episodes: 274/1000
# Number of measured sequences: 72
# Episodes: 276/1000
# Number of measured sequences: 72
# Episodes: 277/1000
# Number of measured sequences: 73
# Episodes: 279/1000
# Number of measured sequences: 73
# Episodes: 281/1000
# Number of measured sequences: 74
# Episodes: 283/1000
# Number of measured sequences: 74
# Episodes: 284/1000
# Number of measured sequences: 75
# Episodes: 286/1000
# Number of measured sequences: 75
# Episodes: 287/1000
# Number of measured sequences: 75
# Episodes: 288/1000
# Number of measured sequences: 76
# Episodes: 290/1000
# Number of measured sequences: 77
# Episodes: 292/1000
# Number of measured sequences: 77
# Episodes: 293/1000
# Number of measured sequences: 77
# Episodes: 295/1000
# Number of measured sequences: 77
# Episodes: 296/1000
# Number of measured sequences: 77
# Episodes: 297/1000
# Number of measured sequences: 77
# Episodes: 298/1000
# Number of measured sequences: 78
# Episodes: 300/1000
# Number of measured sequences: 79
# Episodes: 303/1000
# Number of measured sequences: 79
# Episodes: 304/1000
# Number of measured sequences: 79
# Episodes: 305/1000
# Number of measured sequences: 80
# Episodes: 307/1000
# Number of measured sequences: 81
# Episodes: 309/1000
# Number of measured sequences: 81
# Episodes: 310/1000
# Number of measured sequences: 82
# Episodes: 312/1000
# Number of measured sequences: 83
# Episodes: 315/1000
# Number of measured sequences: 83
# Episodes: 316/1000
# Number of measured sequences: 83
# Episodes: 317/1000
# Number of measured sequences: 84
# Episodes: 319/1000
# Number of measured sequences: 85
# Episodes: 321/1000
# Number of measured sequences: 85
# Episodes: 322/1000
# Number of measured sequences: 86
# Episodes: 324/1000
# Number of measured sequences: 87
# Episodes: 326/1000
# Number of measured sequences: 87
# Episodes: 327/1000
# Number of measured sequences: 87
# Episodes: 329/1000
# Number of measured sequences: 87
# Episodes: 330/1000
# Number of measured sequences: 88
# Episodes: 333/1000
# Number of measured sequences: 88
# Episodes: 334/1000
# Number of measured sequences: 88
# Episodes: 336/1000
# Number of measured sequences: 88
# Episodes: 337/1000
# Number of measured sequences: 89
# Episodes: 339/1000
# Number of measured sequences: 89
# Episodes: 340/1000
# Number of measured sequences: 90
# Episodes: 342/1000
# Number of measured sequences: 90
# Episodes: 343/1000
# Number of measured sequences: 90
# Episodes: 344/1000
# Number of measured sequences: 90
# Episodes: 345/1000
# Number of measured sequences: 91
# Episodes: 347/1000
# Number of measured sequences: 92
# Episodes: 349/1000
# Number of measured sequences: 93
# Episodes: 351/1000
# Number of measured sequences: 93
# Episodes: 352/1000
# Number of measured sequences: 93
# Episodes: 353/1000
# Number of measured sequences: 93
# Episodes: 355/1000
# Number of measured sequences: 93
# Episodes: 356/1000
# Number of measured sequences: 93
# Episodes: 357/1000
# Number of measured sequences: 93
# Episodes: 358/1000
# Number of measured sequences: 94
# Episodes: 360/1000
# Number of measured sequences: 94
# Episodes: 361/1000
# Number of measured sequences: 94
# Episodes: 362/1000
# Number of measured sequences: 95
# Episodes: 364/1000
# Number of measured sequences: 95
# Episodes: 365/1000
# Number of measured sequences: 96
# Episodes: 367/1000
# Number of measured sequences: 96
# Episodes: 369/1000
# Number of measured sequences: 96
# Episodes: 370/1000
# Number of measured sequences: 96
# Episodes: 371/1000
# Number of measured sequences: 97
# Episodes: 373/1000
# Number of measured sequences: 97
# Episodes: 374/1000
# Number of measured sequences: 98
# Episodes: 376/1000
# Number of measured sequences: 98
# Episodes: 377/1000
# Number of measured sequences: 99
# Episodes: 379/1000
# Number of measured sequences: 100
# Episodes: 381/1000
# Number of measured sequences: 101
# Episodes: 383/1000
# Number of measured sequences: 102
# Episodes: 385/1000
# Number of measured sequences: 103
# Episodes: 387/1000
# Number of measured sequences: 103
# Episodes: 388/1000
# Number of measured sequences: 104
# Episodes: 390/1000
# Number of measured sequences: 104
# Episodes: 392/1000
# Number of measured sequences: 105
# New top sequence: (0.9117372434741337, 'GGCGGGGGUCCCGC', 1)
# Episodes: 394/1000
# Number of measured sequences: 106
# Episodes: 396/1000
# Number of measured sequences: 107
# Episodes: 398/1000
# Number of measured sequences: 107
# Episodes: 399/1000
# Number of measured sequences: 107
# Episodes: 400/1000
# Number of measured sequences: 108
# Episodes: 402/1000
# Number of measured sequences: 109
# Episodes: 404/1000
# Number of measured sequences: 110
# Episodes: 406/1000
# Number of measured sequences: 110
# Episodes: 407/1000
# Number of measured sequences: 111
# Episodes: 409/1000
# Number of measured sequences: 112
# Episodes: 411/1000
# Number of measured sequences: 113
# Episodes: 413/1000
# Number of measured sequences: 113
# Episodes: 414/1000
# Number of measured sequences: 113
# Episodes: 416/1000
# Number of measured sequences: 114
# Episodes: 418/1000
# Number of measured sequences: 115
# Episodes: 420/1000
# Number of measured sequences: 115
# Episodes: 421/1000
# Number of measured sequences: 115
# Episodes: 422/1000
# Number of measured sequences: 116
# Episodes: 424/1000
# Number of measured sequences: 116
# Episodes: 425/1000
# Number of measured sequences: 117
# Episodes: 427/1000
# Number of measured sequences: 117
# Episodes: 429/1000
# Number of measured sequences: 117
# Episodes: 431/1000
# Number of measured sequences: 118
# Episodes: 433/1000
# Number of measured sequences: 119
# Episodes: 435/1000
# Number of measured sequences: 119
# Episodes: 437/1000
# Number of measured sequences: 119
# Episodes: 438/1000
# Number of measured sequences: 120
# Episodes: 440/1000
# Number of measured sequences: 121
# Episodes: 442/1000
# Number of measured sequences: 122
# Episodes: 444/1000
# Number of measured sequences: 122
# Episodes: 445/1000
# Number of measured sequences: 123
# Episodes: 447/1000
# Number of measured sequences: 124
# Episodes: 449/1000
# Number of measured sequences: 124
# Episodes: 450/1000
# Number of measured sequences: 124
# Episodes: 451/1000
# Number of measured sequences: 124
# Episodes: 452/1000
# Number of measured sequences: 124
# Episodes: 453/1000
# Number of measured sequences: 125
# Episodes: 455/1000
# Number of measured sequences: 125
# Episodes: 457/1000
# Number of measured sequences: 125
# Episodes: 458/1000
# Number of measured sequences: 126
# Episodes: 460/1000
# Number of measured sequences: 126
# Episodes: 461/1000
# Number of measured sequences: 126
# Episodes: 462/1000
# Number of measured sequences: 126
# Episodes: 463/1000
# Number of measured sequences: 127
# Episodes: 465/1000
# Number of measured sequences: 127
# Episodes: 466/1000
# Number of measured sequences: 128
# Episodes: 468/1000
# Number of measured sequences: 129
# Episodes: 470/1000
# Number of measured sequences: 129
# Episodes: 471/1000
# Number of measured sequences: 130
# Episodes: 473/1000
# Number of measured sequences: 130
# Episodes: 474/1000
# Number of measured sequences: 131
# Episodes: 476/1000
# Number of measured sequences: 132
# Episodes: 478/1000
# Number of measured sequences: 133
# Episodes: 480/1000
# Number of measured sequences: 133
# Episodes: 481/1000
# Number of measured sequences: 134
# Episodes: 484/1000
# Number of measured sequences: 135
# Episodes: 486/1000
# Number of measured sequences: 136
# Episodes: 488/1000
# Number of measured sequences: 136
# Episodes: 489/1000
# Number of measured sequences: 136
# Episodes: 490/1000
# Number of measured sequences: 136
# Episodes: 491/1000
# Number of measured sequences: 136
# Episodes: 492/1000
# Number of measured sequences: 137
# Episodes: 494/1000
# Number of measured sequences: 137
# Episodes: 495/1000
# Number of measured sequences: 137
# Episodes: 496/1000
# Number of measured sequences: 138
# Episodes: 498/1000
# Number of measured sequences: 139
# Episodes: 500/1000
# Number of measured sequences: 140
# Episodes: 502/1000
# Number of measured sequences: 140
# Episodes: 503/1000
# Number of measured sequences: 141
# Episodes: 505/1000
# Number of measured sequences: 141
# Episodes: 506/1000
# Number of measured sequences: 141
# Episodes: 507/1000
# Number of measured sequences: 142
# Episodes: 509/1000
# Number of measured sequences: 143
# Episodes: 511/1000
# Number of measured sequences: 143
# Episodes: 512/1000
# Number of measured sequences: 144
# Episodes: 514/1000
# Number of measured sequences: 145
# Episodes: 516/1000
# Number of measured sequences: 145
# Episodes: 517/1000
# Number of measured sequences: 145
# Episodes: 518/1000
# Number of measured sequences: 145
# Episodes: 519/1000
# Number of measured sequences: 145
# Episodes: 520/1000
# Number of measured sequences: 146
# Episodes: 522/1000
# Number of measured sequences: 147
# Episodes: 524/1000
# Number of measured sequences: 147
# Episodes: 526/1000
# Number of measured sequences: 147
# Episodes: 527/1000
# Number of measured sequences: 147
# Episodes: 528/1000
# Number of measured sequences: 147
# Episodes: 529/1000
# Number of measured sequences: 147
# Episodes: 530/1000
# Number of measured sequences: 147
# Episodes: 531/1000
# Number of measured sequences: 147
# Episodes: 532/1000
# Number of measured sequences: 147
# Episodes: 533/1000
# Number of measured sequences: 147
# Episodes: 534/1000
# Number of measured sequences: 148
# Episodes: 537/1000
# Number of measured sequences: 148
# Episodes: 538/1000
# Number of measured sequences: 148
# Episodes: 539/1000
# Number of measured sequences: 148
# Episodes: 540/1000
# Number of measured sequences: 149
# Episodes: 542/1000
# Number of measured sequences: 150
# Episodes: 544/1000
# Number of measured sequences: 150
# Episodes: 545/1000
# Number of measured sequences: 150
# Episodes: 546/1000
# Number of measured sequences: 150
# Episodes: 547/1000
# Number of measured sequences: 150
# Episodes: 548/1000
# Number of measured sequences: 150
# Episodes: 549/1000
# Number of measured sequences: 151
# Episodes: 552/1000
# Number of measured sequences: 152
# Episodes: 554/1000
# Number of measured sequences: 152
# Episodes: 555/1000
# Number of measured sequences: 153
# Episodes: 557/1000
# Number of measured sequences: 153
# Episodes: 558/1000
# Number of measured sequences: 154
# Episodes: 560/1000
# Number of measured sequences: 154
# Episodes: 561/1000
# Number of measured sequences: 155
# Episodes: 563/1000
# Number of measured sequences: 155
# Episodes: 564/1000
# Number of measured sequences: 156
# Episodes: 566/1000
# Number of measured sequences: 156
# Episodes: 567/1000
# Number of measured sequences: 156
# Episodes: 568/1000
# Number of measured sequences: 156
# Episodes: 569/1000
# Number of measured sequences: 156
# Episodes: 571/1000
# Number of measured sequences: 157
# Episodes: 573/1000
# Number of measured sequences: 157
# Episodes: 575/1000
# Number of measured sequences: 157
# Episodes: 576/1000
# Number of measured sequences: 158
# Episodes: 578/1000
# Number of measured sequences: 159
# Episodes: 580/1000
# Number of measured sequences: 159
# Episodes: 581/1000
# Number of measured sequences: 159
# Episodes: 582/1000
# Number of measured sequences: 159
# Episodes: 583/1000
# Number of measured sequences: 159
# Episodes: 584/1000
# Number of measured sequences: 159
# Episodes: 585/1000
# Number of measured sequences: 159
# Episodes: 586/1000
# Number of measured sequences: 159
# Episodes: 587/1000
# Number of measured sequences: 159
# Episodes: 588/1000
# Number of measured sequences: 160
# Episodes: 590/1000
# Number of measured sequences: 161
# Episodes: 593/1000
# Number of measured sequences: 162
# Episodes: 595/1000
# Number of measured sequences: 162
# Episodes: 596/1000
# Number of measured sequences: 163
# Episodes: 598/1000
# Number of measured sequences: 164
# Episodes: 600/1000
# Number of measured sequences: 165
# Episodes: 602/1000
# Number of measured sequences: 165
# Episodes: 603/1000
# Number of measured sequences: 165
# Episodes: 604/1000
# Number of measured sequences: 166
# Episodes: 606/1000
# Number of measured sequences: 166
# Episodes: 607/1000
# Number of measured sequences: 166
# Episodes: 608/1000
# Number of measured sequences: 166
# Episodes: 609/1000
# Number of measured sequences: 166
# Episodes: 611/1000
# Number of measured sequences: 166
# Episodes: 613/1000
# Number of measured sequences: 166
# Episodes: 615/1000
# Number of measured sequences: 166
# Episodes: 616/1000
# Number of measured sequences: 166
# Episodes: 617/1000
# Number of measured sequences: 167
# Episodes: 619/1000
# Number of measured sequences: 167
# Episodes: 620/1000
# Number of measured sequences: 167
# Episodes: 621/1000
# Number of measured sequences: 167
# Episodes: 622/1000
# Number of measured sequences: 167
# Episodes: 623/1000
# Number of measured sequences: 168
# Episodes: 625/1000
# Number of measured sequences: 168
# Episodes: 626/1000
# Number of measured sequences: 169
# Episodes: 629/1000
# Number of measured sequences: 169
# Episodes: 630/1000
# Number of measured sequences: 169
# Episodes: 631/1000
# Number of measured sequences: 170
# Episodes: 633/1000
# Number of measured sequences: 170
# Episodes: 634/1000
# Number of measured sequences: 170
# Episodes: 635/1000
# Number of measured sequences: 171
# Episodes: 637/1000
# Number of measured sequences: 171
# Episodes: 639/1000
# Number of measured sequences: 171
# Episodes: 640/1000
# Number of measured sequences: 172
# Episodes: 642/1000
# Number of measured sequences: 173
# Episodes: 644/1000
# Number of measured sequences: 173
# Episodes: 646/1000
# Number of measured sequences: 173
# Episodes: 647/1000
# Number of measured sequences: 173
# Episodes: 648/1000
# Number of measured sequences: 173
# Episodes: 649/1000
# Number of measured sequences: 173
# Episodes: 650/1000
# Number of measured sequences: 173
# Episodes: 651/1000
# Number of measured sequences: 174
# Episodes: 653/1000
# Number of measured sequences: 174
# Episodes: 655/1000
# Number of measured sequences: 174
# Episodes: 657/1000
# Number of measured sequences: 175
# Episodes: 659/1000
# Number of measured sequences: 175
# Episodes: 660/1000
# Number of measured sequences: 176
# Episodes: 662/1000
# Number of measured sequences: 177
# Episodes: 664/1000
# Number of measured sequences: 177
# Episodes: 665/1000
# Number of measured sequences: 177
# Episodes: 666/1000
# Number of measured sequences: 177
# Episodes: 667/1000
# Number of measured sequences: 177
# Episodes: 668/1000
# Number of measured sequences: 177
# Episodes: 669/1000
# Number of measured sequences: 177
# Episodes: 670/1000
# Number of measured sequences: 178
# Episodes: 672/1000
# Number of measured sequences: 178
# Episodes: 673/1000
# Number of measured sequences: 178
# Episodes: 674/1000
# Number of measured sequences: 178
# Episodes: 675/1000
# Number of measured sequences: 179
# Episodes: 677/1000
# Number of measured sequences: 180
# Episodes: 679/1000
# Number of measured sequences: 180
# Episodes: 680/1000
# Number of measured sequences: 180
# Episodes: 681/1000
# Number of measured sequences: 181
# Episodes: 683/1000
# Number of measured sequences: 181
# Episodes: 684/1000
# Number of measured sequences: 182
# Episodes: 686/1000
# Number of measured sequences: 182
# Episodes: 687/1000
# Number of measured sequences: 183
# Episodes: 689/1000
# Number of measured sequences: 183
# Episodes: 690/1000
# Number of measured sequences: 184
# Episodes: 692/1000
# Number of measured sequences: 184
# Episodes: 694/1000
# Number of measured sequences: 184
# Episodes: 696/1000
# Number of measured sequences: 184
# Episodes: 697/1000
# Number of measured sequences: 185
# Episodes: 699/1000
# Number of measured sequences: 186
# Episodes: 701/1000
# Number of measured sequences: 186
# Episodes: 702/1000
# Number of measured sequences: 186
# Episodes: 704/1000
# Number of measured sequences: 187
# Episodes: 706/1000
# Number of measured sequences: 187
# Episodes: 708/1000
# Number of measured sequences: 187
# Episodes: 709/1000
# Number of measured sequences: 188
# Episodes: 713/1000
# Number of measured sequences: 188
# Episodes: 714/1000
# Number of measured sequences: 189
# Episodes: 716/1000
# Number of measured sequences: 189
# Episodes: 718/1000
# Number of measured sequences: 189
# Episodes: 719/1000
# Number of measured sequences: 189
# Episodes: 720/1000
# Number of measured sequences: 189
# Episodes: 721/1000
# Number of measured sequences: 190
# Episodes: 723/1000
# Number of measured sequences: 190
# Episodes: 724/1000
# Number of measured sequences: 191
# Episodes: 726/1000
# Number of measured sequences: 191
# Episodes: 727/1000
# Number of measured sequences: 191
# Episodes: 728/1000
# Number of measured sequences: 192
# Episodes: 730/1000
# Number of measured sequences: 193
# Episodes: 732/1000
# Number of measured sequences: 194
# Episodes: 734/1000
# Number of measured sequences: 194
# Episodes: 735/1000
# Number of measured sequences: 194
# Episodes: 736/1000
# Number of measured sequences: 194
# Episodes: 738/1000
# Number of measured sequences: 194
# Episodes: 739/1000
# Number of measured sequences: 194
# Episodes: 740/1000
# Number of measured sequences: 195
# Episodes: 742/1000
# Number of measured sequences: 196
# Episodes: 744/1000
# Number of measured sequences: 196
# Episodes: 745/1000
# Number of measured sequences: 196
# Episodes: 747/1000
# Number of measured sequences: 196
# Episodes: 748/1000
# Number of measured sequences: 196
# Episodes: 749/1000
# Number of measured sequences: 197
# Episodes: 751/1000
# Number of measured sequences: 198
# Episodes: 753/1000
# Number of measured sequences: 198
# Episodes: 755/1000
# Number of measured sequences: 198
# Episodes: 756/1000
# Number of measured sequences: 198
# Episodes: 757/1000
# Number of measured sequences: 199
# Episodes: 759/1000
# Number of measured sequences: 199
# Episodes: 760/1000
# Number of measured sequences: 199
# Episodes: 761/1000
# Number of measured sequences: 199
# Episodes: 763/1000
# Number of measured sequences: 200
# Episodes: 765/1000
# Number of measured sequences: 201
# Episodes: 767/1000
# Number of measured sequences: 201
# Episodes: 768/1000
# Number of measured sequences: 201
# Episodes: 769/1000
# Number of measured sequences: 201
# Episodes: 771/1000
# Number of measured sequences: 201
# Episodes: 773/1000
# Number of measured sequences: 202
# Episodes: 776/1000
# Number of measured sequences: 203
# Episodes: 778/1000
# Number of measured sequences: 203
# Episodes: 780/1000
# Number of measured sequences: 204
# Episodes: 782/1000
# Number of measured sequences: 204
# Episodes: 783/1000
# Number of measured sequences: 204
# Episodes: 785/1000
# Number of measured sequences: 204
# Episodes: 787/1000
# Number of measured sequences: 204
# Episodes: 789/1000
# Number of measured sequences: 204
# Episodes: 791/1000
# Number of measured sequences: 204
# Episodes: 792/1000
# Number of measured sequences: 204
# Episodes: 793/1000
# Number of measured sequences: 204
# Episodes: 794/1000
# Number of measured sequences: 205
# Episodes: 796/1000
# Number of measured sequences: 205
# Episodes: 797/1000
# Number of measured sequences: 205
# Episodes: 798/1000
# Number of measured sequences: 205
# Episodes: 799/1000
# Number of measured sequences: 205
# Episodes: 800/1000
# Number of measured sequences: 205
# Episodes: 801/1000
# Number of measured sequences: 205
# Episodes: 802/1000
# Number of measured sequences: 205
# Episodes: 804/1000
# Number of measured sequences: 205
# Episodes: 805/1000
# Number of measured sequences: 205
# Episodes: 806/1000
# Number of measured sequences: 205
# Episodes: 807/1000
# Number of measured sequences: 206
# Episodes: 809/1000
# Number of measured sequences: 206
# Episodes: 811/1000
# Number of measured sequences: 206
# Episodes: 812/1000
# Number of measured sequences: 207
# Episodes: 814/1000
# Number of measured sequences: 207
# Episodes: 815/1000
# Number of measured sequences: 207
# Episodes: 816/1000
# Number of measured sequences: 207
# Episodes: 817/1000
# Number of measured sequences: 207
# Episodes: 818/1000
# Number of measured sequences: 207
# Episodes: 819/1000
# Number of measured sequences: 207
# Episodes: 821/1000
# Number of measured sequences: 207
# Episodes: 823/1000
# Number of measured sequences: 207
# Episodes: 824/1000
# Number of measured sequences: 208
# Episodes: 826/1000
# Number of measured sequences: 209
# New top sequence: (0.925468225741036, 'GGGGUCCGGCCCGU', 1)
# Episodes: 828/1000
# Number of measured sequences: 209
# Episodes: 829/1000
# Number of measured sequences: 210
# Episodes: 831/1000
# Number of measured sequences: 210
# Episodes: 832/1000
# Number of measured sequences: 211
# Episodes: 834/1000
# Number of measured sequences: 212
# Episodes: 836/1000
# Number of measured sequences: 212
# Episodes: 839/1000
# Number of measured sequences: 212
# Episodes: 840/1000
# Number of measured sequences: 212
# Episodes: 841/1000
# Number of measured sequences: 213
# Episodes: 843/1000
# Number of measured sequences: 213
# Episodes: 844/1000
# Number of measured sequences: 213
# Episodes: 845/1000
# Number of measured sequences: 214
# Episodes: 847/1000
# Number of measured sequences: 215
# Episodes: 849/1000
# Number of measured sequences: 216
# Episodes: 851/1000
# Number of measured sequences: 216
# Episodes: 852/1000
# Number of measured sequences: 216
# Episodes: 853/1000
# Number of measured sequences: 216
# Episodes: 854/1000
# Number of measured sequences: 216
# Episodes: 855/1000
# Number of measured sequences: 217
# Episodes: 857/1000
# Number of measured sequences: 217
# Episodes: 858/1000
# Number of measured sequences: 218
# Episodes: 860/1000
# Number of measured sequences: 218
# Episodes: 861/1000
# Number of measured sequences: 218
# Episodes: 862/1000
# Number of measured sequences: 219
# Episodes: 864/1000
# Number of measured sequences: 220
# Episodes: 866/1000
# Number of measured sequences: 220
# Episodes: 867/1000
# Number of measured sequences: 220
# Episodes: 868/1000
# Number of measured sequences: 221
# Episodes: 870/1000
# Number of measured sequences: 222
# Episodes: 872/1000
# Number of measured sequences: 223
# Episodes: 874/1000
# Number of measured sequences: 223
# Episodes: 875/1000
# Number of measured sequences: 224
# Episodes: 877/1000
# Number of measured sequences: 225
# Episodes: 879/1000
# Number of measured sequences: 226
# Episodes: 881/1000
# Number of measured sequences: 226
# Episodes: 882/1000
# Number of measured sequences: 226
# Episodes: 883/1000
# Number of measured sequences: 227
# Episodes: 885/1000
# Number of measured sequences: 227
# Episodes: 886/1000
# Number of measured sequences: 228
# Episodes: 889/1000
# Number of measured sequences: 228
# Episodes: 890/1000
# Number of measured sequences: 228
# Episodes: 892/1000
# Number of measured sequences: 228
# Episodes: 894/1000
# Number of measured sequences: 228
# Episodes: 895/1000
# Number of measured sequences: 228
# Episodes: 896/1000
# Number of measured sequences: 229
# Episodes: 898/1000
# Number of measured sequences: 229
# Episodes: 900/1000
# Number of measured sequences: 229
# Episodes: 901/1000
# Number of measured sequences: 229
# Episodes: 902/1000
# Number of measured sequences: 230
# Episodes: 904/1000
# Number of measured sequences: 230
# Episodes: 905/1000
# Number of measured sequences: 231
# Episodes: 907/1000
# Number of measured sequences: 231
# Episodes: 908/1000
# Number of measured sequences: 231
# Episodes: 909/1000
# Number of measured sequences: 231
# Episodes: 910/1000
# Number of measured sequences: 231
# Episodes: 911/1000
# Number of measured sequences: 231
# Episodes: 912/1000
# Number of measured sequences: 232
# Episodes: 914/1000
# Number of measured sequences: 232
# Episodes: 915/1000
# Number of measured sequences: 232
# Episodes: 916/1000
# Number of measured sequences: 232
# Episodes: 917/1000
# Number of measured sequences: 232
# Episodes: 918/1000
# Number of measured sequences: 232
# Episodes: 919/1000
# Number of measured sequences: 232
# Episodes: 920/1000
# Number of measured sequences: 232
# Episodes: 921/1000
# Number of measured sequences: 233
# Episodes: 923/1000
# Number of measured sequences: 233
# Episodes: 925/1000
# Number of measured sequences: 234
# Episodes: 927/1000
# Number of measured sequences: 235
# Episodes: 929/1000
# Number of measured sequences: 236
# Episodes: 931/1000
# Number of measured sequences: 236
# Episodes: 932/1000
# Number of measured sequences: 236
# Episodes: 933/1000
# Number of measured sequences: 236
# Episodes: 934/1000
# Number of measured sequences: 236
# Episodes: 935/1000
# Number of measured sequences: 236
# Episodes: 936/1000
# Number of measured sequences: 237
# New top sequence: (0.9858845686672226, 'GGCGGGGGCCCCGC', 1)
# Episodes: 938/1000
# Number of measured sequences: 238
# Episodes: 940/1000
# Number of measured sequences: 239
# Episodes: 942/1000
# Number of measured sequences: 239
# Episodes: 943/1000
# Number of measured sequences: 240
# Episodes: 945/1000
# Number of measured sequences: 240
# Episodes: 946/1000
# Number of measured sequences: 240
# Episodes: 947/1000
# Number of measured sequences: 240
# Episodes: 948/1000
# Number of measured sequences: 240
# Episodes: 949/1000
# Number of measured sequences: 240
# Episodes: 950/1000
# Number of measured sequences: 240
# Episodes: 951/1000
# Number of measured sequences: 240
# Episodes: 952/1000
# Number of measured sequences: 240
# Episodes: 953/1000
# Number of measured sequences: 240
# Episodes: 954/1000
# Number of measured sequences: 241
# Episodes: 956/1000
# Number of measured sequences: 242
# Episodes: 958/1000
# Number of measured sequences: 243
# Episodes: 960/1000
# Number of measured sequences: 243
# Episodes: 961/1000
# Number of measured sequences: 243
# Episodes: 962/1000
# Number of measured sequences: 243
# Episodes: 963/1000
# Number of measured sequences: 243
# Episodes: 964/1000
# Number of measured sequences: 243
# Episodes: 965/1000
# Number of measured sequences: 243
# Episodes: 966/1000
# Number of measured sequences: 244
# Episodes: 968/1000
# Number of measured sequences: 244
# Episodes: 969/1000
# Number of measured sequences: 244
# Episodes: 970/1000
# Number of measured sequences: 245
# Episodes: 972/1000
# Number of measured sequences: 245
# Episodes: 973/1000
# Number of measured sequences: 245
# Episodes: 975/1000
# Number of measured sequences: 246
# Episodes: 977/1000
# Number of measured sequences: 247
# Episodes: 979/1000
# Number of measured sequences: 247
# Episodes: 980/1000
# Number of measured sequences: 247
# Episodes: 981/1000
# Number of measured sequences: 248
# Episodes: 983/1000
# Number of measured sequences: 249
# Episodes: 985/1000
# Number of measured sequences: 250
# Episodes: 987/1000
# Number of measured sequences: 250
# Episodes: 988/1000
# Number of measured sequences: 250
# Episodes: 989/1000
# Number of measured sequences: 250
# Episodes: 990/1000
# Number of measured sequences: 251
# Episodes: 992/1000
# Number of measured sequences: 252
# Episodes: 994/1000
# Number of measured sequences: 252
# Episodes: 996/1000
# Number of measured sequences: 252
# Episodes: 997/1000
# Number of measured sequences: 252
# Episodes: 998/1000
# Number of measured sequences: 253
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# ...
# Episodes: 959/1000
# Number of measured sequences: 268
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Proposing samples...
# Evaluating scalability.
# loading landscapes RNA: [0, 1, 12, 20, 25, 31], TF:[]
# B1L14RNA1 loaded
# B1L50RNA1 loaded
# B2L14RNA1+2 loaded
# B2L50RNA1+4 loaded
# B2L100RNA1+3 loaded
# C20B2L100RNA1+3 loaded
# 0 TF landscapes loaded.
# loading complete
# Running on B1L14RNA1
# start seq startRNAL14_0
# Evaluating for virtual_screen: 1, batch_size: 100
# Episodes: 0/1000
# /Users/richard/Documents/Research/FLSD-Sandbox/models/Ground_truth_oracles/RNA_landscape_models.py:21: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   self.loaded_landscapes = yaml.load(cfgfile)
# Number of measured sequences: 28
# New top sequence: (0.7222496462872485, 'AUGGGCCGGGCCCC', 1)
# Episodes: 153/1000
# Number of measured sequences: 68
# Episodes: 300/1000
# Number of measured sequences: 119
# New top sequence: (0.8320975044224674, 'AUGGGCCGGGCGGC', 1)
# Episodes: 454/1000
# Number of measured sequences: 168
# Episodes: 609/1000
# Number of measured sequences: 218
# Episodes: 762/1000
# Number of measured sequences: 260
# Episodes: 909/1000
# Number of measured sequences: 289
# Proposing samples...
# Proposing samples...
# Proposing samples...
# B1L14RNA1,100,1,22.61908721923828
#
# Evaluating for virtual_screen: 10, batch_size: 100
# Episodes: 0/1000
# Number of measured sequences: 43
# New top sequence: (0.7222496462872485, 'AUGGGCCGGGCCCC', 1)
# Episodes: 159/1000
# Number of measured sequences: 93
# New top sequence: (0.7304882670751143, 'GUGGGCCGGGCCCC', 1)
# Episodes: 323/1000
# Number of measured sequences: 148
# New top sequence: (0.7909045576217604, 'CCGCGCGGGACCCC', 1)
# Episodes: 501/1000
# Number of measured sequences: 197
# Episodes: 670/1000
# Number of measured sequences: 244
# Episodes: 831/1000
# Number of measured sequences: 287
# Episodes: 987/1000
# Number of measured sequences: 290
# Proposing samples...
# Proposing samples...
# Proposing samples...
# B1L14RNA1,100,10,23.164401054382324
#
# Evaluating for virtual_screen: 100, batch_size: 100
# Episodes: 0/1000
# Number of measured sequences: 32
# New top sequence: (0.6535947349527367, 'AUGGGCCGCCCCCC', 1)
# Episodes: 150/1000
# Number of measured sequences: 81
# New top sequence: (0.6618333557406024, 'AUGGGCCCGAGCCC', 1)
# Episodes: 318/1000
# Number of measured sequences: 136
# New top sequence: (0.7524578177503418, 'UUGCCCCGGGCCCC', 1)
# Episodes: 487/1000
# Number of measured sequences: 184
# Episodes: 653/1000
# Number of measured sequences: 229
# New top sequence: (0.8266051429434308, 'AUGGCGGGGGCCCC', 1)
# Episodes: 811/1000
# Number of measured sequences: 278
# Episodes: 976/1000
# Number of measured sequences: 283
# Proposing samples...
# Proposing samples...
# Proposing samples...
# B1L14RNA1,100,100,22.966374158859253
#
# Evaluating for virtual_screen: 1, batch_size: 1000
# Episodes: 0/1000
# Number of measured sequences: 42
# New top sequence: (0.7222496462872485, 'AUGGGCCGGGCCCC', 1)
# Proposing samples...
# ---------------------------------------------------------------------------
# _FallbackException                        Traceback (most recent call last)
# ~/Documents/Research/FLRL/venv/lib/python3.7/site-packages/tensorflow_core/python/ops/gen_array_ops.py in reshape(tensor, shape, name)
#    8100         _ctx._context_handle, _ctx._thread_local_data.device_name, "Reshape",
# -> 8101         name, _ctx._post_execution_callbacks, tensor, shape)
#    8102       return _result
#
# _FallbackException: This function does not handle the case of the path where all inputs are not already EagerTensors.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-36ba286e728a> in <module>
#      16 evaluator_ppo = Evaluator(ppo_explorer, landscape_types=RNA_LANDSCAPE_TYPES, path="../simulations/eval/RNA/")
#      17 evaluator_ppo.verbose = False
# ---> 18 evaluator_ppo.evaluate_for_landscapes(evaluator_ppo.scalability, num_starts=num_starts)
#      19
#      20 print("Evaluating consistency.")
#
# ~/Documents/Research/FLSD-Sandbox/evaluators/Evaluator.py in evaluate_for_landscapes(self, property_of_interest_evaluator, num_starts)
#     134                       start_seq_id = starting_seq
#     135                       start_seq = landscape["starting_seqs"][starting_seq]
# --> 136                       property_of_interest_evaluator(oracle, start_seq, landscape_id, start_seq_id)
#     137                       starts_per_landscape += 1
#     138                       if starts_per_landscape >= num_starts:
#
# ~/Documents/Research/FLSD-Sandbox/evaluators/Evaluator.py in scalability(self, oracle, start_seq, landscape_id, start_seq_id)
#     211                     self.explorer.virtual_screen = virtual_screen
#     212                     start = time.time()
# --> 213                     self.run_on_NAM(oracle,landscape_idents, start_seq, num_batches=3)
#     214                     end = time.time()
#     215                     time_needed = end-start
#
# ~/Documents/Research/FLSD-Sandbox/evaluators/Evaluator.py in run_on_NAM(self, landscape_oracle, NAM_args, start_seq, num_batches, hot_start, verbose, overwrite)
#     101            noisy_landscape.reset([start_seq])
#     102         self.explorer.set_model(noisy_landscape)
# --> 103         self.explorer.run(num_batches, overwrite= overwrite, verbose=self.verbose)
#     104
#     105     def run_on_NNmodel(self, landscape_oracle, NNM_args, start_seq , num_batches = 10, hot_start = False, verbose = False, overwrite = False, ):
#
# ~/Documents/Research/FLSD-Sandbox/explorers/base_explorer.py in run(self, rounds, overwrite, verbose)
#      75             if verbose:
#      76                print (f'round: {r}, cost: {self.model.cost}, evals: {self.model.evals}, top: {max(self.model.measured_sequences.values())}')
# ---> 77             new_samples = self.propose_samples()
#      78             self.measure_proposals(new_samples)
#      79             if not self.debug:
#
# ~/Documents/Research/FLSD-Sandbox/explorers/PPO_explorer.py in propose_samples(self)
#     226
#     227         while len(new_seqs.difference(all_seqs)) < self.batch_size:
# --> 228             collect_driver.run()
#     229
#     230         new_seqs = new_seqs.difference(all_seqs)
#
# ~/Documents/Research/FLRL/venv/lib/python3.7/site-packages/tf_agents/drivers/dynamic_episode_driver.py in run(self, time_step, policy_state, num_episodes, maximum_iterations)
#     191         policy_state=policy_state,
#     192         num_episodes=num_episodes,
# --> 193         maximum_iterations=maximum_iterations)
#     194
#     195   def _run(self,
#
# ~/Documents/Research/FLRL/venv/lib/python3.7/site-packages/tf_agents/utils/common.py in with_check_resource_vars(*fn_args, **fn_kwargs)
#     122         # We're either in eager mode or in tf.function mode (no in-between); so
#     123         # autodep-like behavior is already expected of fn.
# --> 124         return fn(*fn_args, **fn_kwargs)
#     125       if not resource_variables_enabled():
#     126         raise RuntimeError(MISSING_RESOURCE_VARIABLES_ERROR)
#
# ~/Documents/Research/FLRL/venv/lib/python3.7/site-packages/tf_agents/drivers/dynamic_episode_driver.py in _run(self, time_step, policy_state, num_episodes, maximum_iterations)
#     219         parallel_iterations=1,
#     220         maximum_iterations=maximum_iterations,
# --> 221         name='driver_loop')
#     222     return time_step, policy_state
#
# ~/Documents/Research/FLRL/venv/lib/python3.7/site-packages/tensorflow_core/python/ops/control_flow_ops.py in while_loop_v2(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#    2476       name=name,
#    2477       maximum_iterations=maximum_iterations,
# -> 2478       return_same_structure=True)
#    2479
#    2480
#
# ~/Documents/Research/FLRL/venv/lib/python3.7/site-packages/tensorflow_core/python/ops/control_flow_ops.py in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#    2712                                               list(loop_vars))
#    2713       while cond(*loop_vars):
# -> 2714         loop_vars = body(*loop_vars)
#    2715         if try_to_pack and not isinstance(loop_vars, (list, _basetuple)):
#    2716           packed = True
#
# ~/Documents/Research/FLRL/venv/lib/python3.7/site-packages/tf_agents/drivers/dynamic_episode_driver.py in loop_body(counter, time_step, policy_state)
#     120         loop_vars for next iteration of tf.while_loop.
#     121       """
# --> 122       action_step = self.policy.action(time_step, policy_state)
#     123
#     124       # TODO(b/134487572): TF2 while_loop seems to either ignore
#
# ~/Documents/Research/FLRL/venv/lib/python3.7/site-packages/tf_agents/policies/tf_policy.py in action(self, time_step, policy_state, seed)
#     248     if self._automatic_state_reset:
#     249       policy_state = self._maybe_reset_state(time_step, policy_state)
# --> 250     step = action_fn(time_step=time_step, policy_state=policy_state, seed=seed)
#     251
#     252     def clip_action(action, action_spec):
#
# ~/Documents/Research/FLRL/venv/lib/python3.7/site-packages/tf_agents/utils/common.py in with_check_resource_vars(*fn_args, **fn_kwargs)
#     122         # We're either in eager mode or in tf.function mode (no in-between); so
#     123         # autodep-like behavior is already expected of fn.
# --> 124         return fn(*fn_args, **fn_kwargs)
#     125       if not resource_variables_enabled():
#     126         raise RuntimeError(MISSING_RESOURCE_VARIABLES_ERROR)
#
# ~/Documents/Research/FLRL/venv/lib/python3.7/site-packages/tf_agents/policies/tf_policy.py in _action(self, time_step, policy_state, seed)
#     431     """
#     432     seed_stream = tfd.SeedStream(seed=seed, salt='ppo_policy')
# --> 433     distribution_step = self._distribution(time_step, policy_state)
#     434     actions = tf.nest.map_structure(
#     435         lambda d: reparameterized_sampling.sample(d, seed=seed_stream()),
#
# ~/Documents/Research/FLRL/venv/lib/python3.7/site-packages/tf_agents/agents/ppo/ppo_policy.py in _distribution(self, time_step, policy_state)
#     133     # Actor network outputs nested structure of distributions or actions.
#     134     actions_or_distributions, policy_state = self._apply_actor_network(
# --> 135         time_step, policy_state)
#     136
#     137     def _to_distribution(action_or_distribution):
#
# ~/Documents/Research/FLRL/venv/lib/python3.7/site-packages/tf_agents/agents/ppo/ppo_policy.py in _apply_actor_network(self, time_step, policy_state)
#     121                               time_step.discount, observation)
#     122     return self._actor_network(
# --> 123         time_step.observation, time_step.step_type, network_state=policy_state)
#     124
#     125   def _variables(self):
#
# ~/Documents/Research/FLRL/venv/lib/python3.7/site-packages/tf_agents/networks/network.py in __call__(self, inputs, *args, **kwargs)
#     169   def __call__(self, inputs, *args, **kwargs):
#     170     tf.nest.assert_same_structure(inputs, self.input_tensor_spec)
# --> 171     return super(Network, self).__call__(inputs, *args, **kwargs)
#     172
#     173
#
# ~/Documents/Research/FLRL/venv/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     889           with base_layer_utils.autocast_context_manager(
#     890               self._compute_dtype):
# --> 891             outputs = self.call(cast_inputs, *args, **kwargs)
#     892           self._handle_activity_regularization(inputs, outputs)
#     893           self._set_mask_metadata(inputs, outputs, input_masks)
#
# ~/Documents/Research/FLRL/venv/lib/python3.7/site-packages/tf_agents/networks/actor_distribution_network.py in call(self, observations, step_type, network_state, training)
#     169     outer_rank = nest_utils.get_outer_rank(observations, self.input_tensor_spec)
#     170     output_actions = tf.nest.map_structure(
# --> 171         lambda proj_net: proj_net(state, outer_rank), self._projection_networks)
#     172     return output_actions, network_state
#
# ~/Documents/Research/FLRL/venv/lib/python3.7/site-packages/tensorflow_core/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     533
#     534   return pack_sequence_as(
# --> 535       structure[0], [func(*x) for x in entries],
#     536       expand_composites=expand_composites)
#     537
#
# ~/Documents/Research/FLRL/venv/lib/python3.7/site-packages/tensorflow_core/python/util/nest.py in <listcomp>(.0)
#     533
#     534   return pack_sequence_as(
# --> 535       structure[0], [func(*x) for x in entries],
#     536       expand_composites=expand_composites)
#     537
#
# ~/Documents/Research/FLRL/venv/lib/python3.7/site-packages/tf_agents/networks/actor_distribution_network.py in <lambda>(proj_net)
#     169     outer_rank = nest_utils.get_outer_rank(observations, self.input_tensor_spec)
#     170     output_actions = tf.nest.map_structure(
# --> 171         lambda proj_net: proj_net(state, outer_rank), self._projection_networks)
#     172     return output_actions, network_state
#
# ~/Documents/Research/FLRL/venv/lib/python3.7/site-packages/tf_agents/networks/network.py in __call__(self, inputs, *args, **kwargs)
#     169   def __call__(self, inputs, *args, **kwargs):
#     170     tf.nest.assert_same_structure(inputs, self.input_tensor_spec)
# --> 171     return super(Network, self).__call__(inputs, *args, **kwargs)
#     172
#     173
#
# ~/Documents/Research/FLRL/venv/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     889           with base_layer_utils.autocast_context_manager(
#     890               self._compute_dtype):
# --> 891             outputs = self.call(cast_inputs, *args, **kwargs)
#     892           self._handle_activity_regularization(inputs, outputs)
#     893           self._set_mask_metadata(inputs, outputs, input_masks)
#
# ~/Documents/Research/FLRL/venv/lib/python3.7/site-packages/tf_agents/networks/normal_projection_network.py in call(self, inputs, outer_rank)
#     166     else:
#     167       stds = self._bias(tf.zeros_like(means))
# --> 168       stds = tf.reshape(stds, [-1] + self._sample_spec.shape.as_list())
#     169
#     170     if self._std_transform is not None:
#
# ~/Documents/Research/FLRL/venv/lib/python3.7/site-packages/tensorflow_core/python/ops/array_ops.py in reshape(tensor, shape, name)
#     129     A `Tensor`. Has the same type as `tensor`.
#     130   """
# --> 131   result = gen_array_ops.reshape(tensor, shape, name)
#     132   tensor_util.maybe_set_static_shape(result, shape)
#     133   return result
#
# ~/Documents/Research/FLRL/venv/lib/python3.7/site-packages/tensorflow_core/python/ops/gen_array_ops.py in reshape(tensor, shape, name)
#    8104       try:
#    8105         return reshape_eager_fallback(
# -> 8106             tensor, shape, name=name, ctx=_ctx)
#    8107       except _core._SymbolicException:
#    8108         pass  # Add nodes to the TensorFlow graph.
#
# ~/Documents/Research/FLRL/venv/lib/python3.7/site-packages/tensorflow_core/python/ops/gen_array_ops.py in reshape_eager_fallback(tensor, shape, name, ctx)
#    8138   _ctx = ctx if ctx else _context.context()
#    8139   _attr_T, (tensor,) = _execute.args_to_matching_eager([tensor], _ctx)
# -> 8140   _attr_Tshape, (shape,) = _execute.args_to_matching_eager([shape], _ctx, _dtypes.int32)
#    8141   _inputs_flat = [tensor, shape]
#    8142   _attrs = ("T", _attr_T, "Tshape", _attr_Tshape)
#
# ~/Documents/Research/FLRL/venv/lib/python3.7/site-packages/tensorflow_core/python/eager/execute.py in args_to_matching_eager(l, ctx, default_dtype)
#     256           internal_convert_to_tensor(
#     257               t, dtype, preferred_dtype=default_dtype, ctx=ctx))
# --> 258       if dtype is None:
#     259         dtype = ret[-1].dtype
#     260   else:
#
# KeyboardInterrupt:

# %%
ppo_explorer = PPO_explorer()
ppo_explorer.debug = False

num_starts = 5
print("Evaluating adaptivity.")
evaluator_ppo = Evaluator(ppo_explorer, landscape_types=TF_LANDSCAPE_TYPES, path="../simulations/eval/TF/")
evaluator_ppo.verbose = False
evaluator_ppo.evaluate_for_landscapes(evaluator_ppo.adaptivity, num_starts=num_starts)

print("Evaluating efficiency.")
evaluator_ppo = Evaluator(ppo_explorer, landscape_types=TF_LANDSCAPE_TYPES, path="../simulations/eval/TF/")
evaluator_ppo.verbose = False
evaluator_ppo.evaluate_for_landscapes(evaluator_ppo.efficiency, num_starts=num_starts)

print("Evaluating scalability.")
evaluator_ppo = Evaluator(ppo_explorer, landscape_types=TF_LANDSCAPE_TYPES, path="../simulations/eval/TF/")
evaluator_ppo.verbose = False
evaluator_ppo.evaluate_for_landscapes(evaluator_ppo.scalability, num_starts=num_starts)

print("Evaluating consistency.")
evaluator_ppo = Evaluator(ppo_explorer, landscape_types=TF_LANDSCAPE_TYPES, path="../simulations/eval/TF/")
evaluator_ppo.verbose = False
evaluator_ppo.evaluate_for_landscapes(evaluator_ppo.consistency_robustness_independence, num_starts=num_starts)

# %%
cmaes_explorer = CMAES_explorer()
cmaes_explorer.debug = False

num_starts = 3
print("Evaluating adaptivity.")
evaluator_cmaes = Evaluator(cmaes_explorer, landscape_types=RNA_LANDSCAPE_TYPES, path="../simulations/eval/RNA/")
evaluator_cmaes.verbose = False
evaluator_cmaes.evaluate_for_landscapes(evaluator_cmaes.adaptivity, num_starts=num_starts)

print("Evaluating efficiency.")
evaluator_cmaes = Evaluator(cmaes_explorer, landscape_types=RNA_LANDSCAPE_TYPES, path="../simulations/eval/RNA/")
evaluator_cmaes.verbose = False
evaluator_cmaes.evaluate_for_landscapes(evaluator_cmaes.efficiency, num_starts=num_starts)

print("Evaluating scalability.")
evaluator_cmaes = Evaluator(cmaes_explorer, landscape_types=RNA_LANDSCAPE_TYPES, path="../simulations/eval/RNA/")
evaluator_cmaes.verbose = False
evaluator_cmaes.evaluate_for_landscapes(evaluator_cmaes.scalability, num_starts=num_starts)

print("Evaluating consistency.")
evaluator_cmaes = Evaluator(cmaes_explorer, landscape_types=RNA_LANDSCAPE_TYPES, path="../simulations/eval/RNA/")
evaluator_cmaes.verbose = False
evaluator_cmaes.evaluate_for_landscapes(evaluator_cmaes.consistency_robustness_independence, num_starts=num_starts)

# %%
cmaes_explorer = CMAES_explorer()
cmaes_explorer.debug = False

num_starts = 5
print("Evaluating adaptivity.")
evaluator_cmaes = Evaluator(cmaes_explorer, landscape_types=TF_LANDSCAPE_TYPES, path="../simulations/eval/TF/")
evaluator_cmaes.verbose = False
evaluator_cmaes.evaluate_for_landscapes(evaluator_cmaes.adaptivity, num_starts=num_starts)

print("Evaluating efficiency.")
evaluator_cmaes = Evaluator(cmaes_explorer, landscape_types=TF_LANDSCAPE_TYPES, path="../simulations/eval/TF/")
evaluator_cmaes.verbose = False
evaluator_cmaes.evaluate_for_landscapes(evaluator_cmaes.efficiency, num_starts=num_starts)

print("Evaluating scalability.")
evaluator_cmaes = Evaluator(cmaes_explorer, landscape_types=TF_LANDSCAPE_TYPES, path="../simulations/eval/TF/")
evaluator_cmaes.verbose = False
evaluator_cmaes.evaluate_for_landscapes(evaluator_cmaes.scalability, num_starts=num_starts)

print("Evaluating consistency.")
evaluator_cmaes = Evaluator(cmaes_explorer, landscape_types=TF_LANDSCAPE_TYPES, path="../simulations/eval/TF/")
evaluator_cmaes.verbose = False
evaluator_cmaes.evaluate_for_landscapes(evaluator_cmaes.consistency_robustness_independence, num_starts=num_starts)

# %%
dynappo_explorer = DynaPPO_explorer()
dynappo_explorer.debug = False

num_starts = 3
print("Evaluating adaptivity.")
evaluator_dynappo = Evaluator(dynappo_explorer, landscape_types=RNA_LANDSCAPE_TYPES, path="../simulations/eval/RNA/")
evaluator_dynappo.verbose = False
evaluator_dynappo.evaluate_for_landscapes(evaluator_dynappo.adaptivity, num_starts=num_starts)

print("Evaluating efficiency.")
evaluator_dynappo = Evaluator(dynappo_explorer, landscape_types=RNA_LANDSCAPE_TYPES, path="../simulations/eval/RNA/")
evaluator_dynappo.verbose = False
evaluator_dynappo.evaluate_for_landscapes(evaluator_dynappo.efficiency, num_starts=num_starts)

print("Evaluating scalability.")
evaluator_dynappo = Evaluator(dynappo_explorer, landscape_types=RNA_LANDSCAPE_TYPES, path="../simulations/eval/RNA/")
evaluator_dynappo.verbose = False
evaluator_dynappo.evaluate_for_landscapes(evaluator_dynappo.scalability, num_starts=num_starts)

print("Evaluating consistency.")
evaluator_dynappo = Evaluator(dynappo_explorer, landscape_types=RNA_LANDSCAPE_TYPES, path="../simulations/eval/RNA/")
evaluator_dynappo.verbose = False
evaluator_dynappo.evaluate_for_landscapes(evaluator_dynappo.consistency_robustness_independence, num_starts=num_starts)

# %%
dynappo_explorer = DynaPPO_explorer()
dynappo_explorer.debug = False

num_starts = 5
print("Evaluating adaptivity.")
evaluator_dynappo = Evaluator(dynappo_explorer, landscape_types=TF_LANDSCAPE_TYPES, path="../simulations/eval/TF/")
evaluator_dynappo.verbose = False
evaluator_dynappo.evaluate_for_landscapes(evaluator_dynappo.adaptivity, num_starts=num_starts)

print("Evaluating efficiency.")
evaluator_dynappo = Evaluator(dynappo_explorer, landscape_types=TF_LANDSCAPE_TYPES, path="../simulations/eval/TF/")
evaluator_dynappo.verbose = False
evaluator_dynappo.evaluate_for_landscapes(evaluator_dynappo.efficiency, num_starts=num_starts)

print("Evaluating scalability.")
evaluator_dynappo = Evaluator(dynappo_explorer, landscape_types=TF_LANDSCAPE_TYPES, path="../simulations/eval/TF/")
evaluator_dynappo.verbose = False
evaluator_dynappo.evaluate_for_landscapes(evaluator_dynappo.scalability, num_starts=num_starts)

print("Evaluating consistency.")
evaluator_dynappo = Evaluator(dynappo_explorer, landscape_types=TF_LANDSCAPE_TYPES, path="../simulations/eval/TF/")
evaluator_dynappo.verbose = False
evaluator_dynappo.evaluate_for_landscapes(evaluator_dynappo.consistency_robustness_independence, num_starts=num_starts)
