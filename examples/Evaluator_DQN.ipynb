# %%
# %matplotlib inline
import sys
sys.path.append('../')
import RNA 
from utils.sequence_utils import generate_random_mutant
from utils.model_architectures import Linear, NLNN, CNNa
from models.Noisy_models.Neural_network_models import NN_model
from models.Ground_truth_oracles.RNA_landscape_models import RNA_landscape_constructor
from models.Noisy_models.Ensemble import Ensemble_models
from evaluators.Evaluator import Evaluator
from models.Ground_truth_oracles.TF_binding_landscape_models import *
from explorers.bo_explorer import BO_Explorer
from explorers.dqn_explorer import DQN_Explorer 

LANDSCAPE_TYPES ={"RNA": [0, 1], 'TF':['SIX6_REF_R1']} # for testing 
LANDSCAPE_TYPES_RNA = {"RNA" : [0,1,12,20,25,31], "TF": []}
LANDSCAPE_TYPES_TF = {"RNA": [], 
                      "TF": ['POU3F4_REF_R1','PAX3_G48R_R1','SIX6_REF_R1', 'VAX2_REF_R1', 'VSX1_REF_R1']}

# %%
dqn_explorer_prod = DQN_Explorer(train_epochs=10)
dqn_explorer_prod.debug = False

# %%
evaluator_dqn=Evaluator(dqn_explorer_prod,landscape_types=LANDSCAPE_TYPES_RNA, path="../simulations/eval/")
evaluator_dqn.evaluate_for_landscapes(evaluator_dqn.consistency_robustness_independence, num_starts=3)
# Out:
# loading landscapes RNA: [0, 1, 12, 20, 25, 31], TF:[]
# B1L14RNA1 loaded
# B1L50RNA1 loaded
# B2L14RNA1+2 loaded
# B2L50RNA1+4 loaded
# B2L100RNA1+3 loaded
# C20B2L100RNA1+3 loaded
# 0 TF landscapes loaded.
# loading complete
# Running on B1L14RNA1
# start seq startRNAL14_0
# Evaluating for signal_strength: 0
# Running  NAM {'landscape_id': 'B1L14RNA1', 'start_id': 'startRNAL14_0', 'signal_strength': 0}
# [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# round: 0, cost: 1, evals: 0.0, top: 0.5437468768175177
# ../models/Ground_truth_oracles/RNA_landscape_models.py:21: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   self.loaded_landscapes = yaml.load(cfgfile)
# [0.4905656058905926, 0.289715783538605, 0.21971861057080233]
# round: 1, cost: 101, evals: 807.0, top: 0.5437468768175177
# [0.552268609128307, 0.02024989937752104, 0.42748149149417186]
# round: 2, cost: 201, evals: 1518.0, top: 0.5931784444060906
# [0.3599422047851907, 0.04692464029574384, 0.5931331549190654]
# round: 3, cost: 300, evals: 2087.0, top: 0.5931784444060906
# [0.04009074024494038, 0.9459065828200275, 0.014002676935032037]
# round: 4, cost: 400, evals: 2570.0, top: 0.5931784444060906
# [0.030377214969595293, 0.5182928625934774, 0.4513299224369273]
# round: 5, cost: 499, evals: 2796.0, top: 0.5931784444060906
# [0.04726504971701194, 0.013762265934845955, 0.9389726843481421]
# round: 6, cost: 599, evals: 2986.0, top: 0.5931784444060906
# [0.10590281919942786, 0.38986023503797446, 0.5042369457625977]
# round: 7, cost: 697, evals: 3214.0, top: 0.5931784444060906
# [0.7760147048842183, 0.04506953741156921, 0.17891575770421234]
# round: 8, cost: 797, evals: 3401.0, top: 0.5931784444060906
# [0.6893283366996861, 0.2972392867607426, 0.0134323765395712]
# round: 9, cost: 895, evals: 3618.0, top: 0.5931784444060906
# [0.19398877092658762, 0.14205342671214977, 0.6639578023612627]
# Evaluating for signal_strength: 0.5
# Running  NAM {'landscape_id': 'B1L14RNA1', 'start_id': 'startRNAL14_0', 'signal_strength': 0.5}
# [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# round: 0, cost: 1, evals: 0.0, top: 0.5437468768175177
# [0.42548577597940296, 0.3313520906021099, 0.24316213341848697]
# round: 1, cost: 101, evals: 722.0, top: 0.6426099596151229
# [0.6936994010194041, 0.27684500176514876, 0.029455597215447153]
# round: 2, cost: 201, evals: 1453.0, top: 0.6426099596151229
# [0.149789450037296, 0.15477487106477017, 0.6954356788979338]
# round: 3, cost: 300, evals: 2194.0, top: 0.6426099596151229
# [0.36028950329191417, 0.6286043791497491, 0.011106117558336678]
# round: 4, cost: 400, evals: 2940.0, top: 0.6426099596151229
# [0.2879254709592226, 0.4971331570924022, 0.21494137194837523]
# round: 5, cost: 500, evals: 3682.0, top: 0.6426099596151229
# [0.561731953565976, 0.06064067883714489, 0.377627367596879]
# round: 6, cost: 600, evals: 4429.0, top: 0.6426099596151229
# [0.13490545280902852, 0.7801794933855567, 0.08491505380541484]
# round: 7, cost: 700, evals: 5173.0, top: 0.6426099596151229
# [0.27492748429334585, 0.28642073362660875, 0.43865178208004546]
# round: 8, cost: 800, evals: 5930.0, top: 0.6947876817534437
# [0.13295210265280405, 0.8490069625128601, 0.018040934834335807]
# round: 9, cost: 900, evals: 6681.0, top: 0.6947876817534437
# [0.015516431614583834, 0.43427813989691505, 0.5502054284885011]
# Evaluating for signal_strength: 0.9
# Running  NAM {'landscape_id': 'B1L14RNA1', 'start_id': 'startRNAL14_0', 'signal_strength': 0.9}
# [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# round: 0, cost: 1, evals: 0.0, top: 0.5437468768175177
# [0.5740997144066662, 0.2131179929573764, 0.21278229263595738]
# round: 1, cost: 101, evals: 702.0, top: 0.5464930837468063
# [0.22388743064279107, 0.4750081268211849, 0.30110444253602403]
# round: 2, cost: 201, evals: 1446.0, top: 0.5464930837468063
# [0.3324485266087417, 0.2815360990681979, 0.38601537432306054]
# round: 3, cost: 301, evals: 1919.0, top: 0.6096556336022815
# [0.4514278530924121, 0.2591351266877192, 0.2894370202198686]
# round: 4, cost: 401, evals: 2019.0, top: 0.6096556336022815
# [0.32808919048851354, 0.24243587142706507, 0.4294749380844215]
# round: 5, cost: 499, evals: 2117.0, top: 0.6453561665444114
# [0.43841789088494365, 0.1524768216458015, 0.40910528746925484]
# round: 6, cost: 597, evals: 2215.0, top: 0.6453561665444114
# [0.3797245966091642, 0.3918985668826349, 0.22837683650820087]
# round: 7, cost: 695, evals: 2313.0, top: 0.6453561665444114
# [0.16094909907966523, 0.3959900485027023, 0.44306085241763254]
# round: 8, cost: 793, evals: 2411.0, top: 0.6453561665444114
# [0.17448098497237932, 0.3789019367058346, 0.4466170783217862]
# round: 9, cost: 891, evals: 2509.0, top: 0.6453561665444114
# [0.4007996189906715, 0.2347782573537941, 0.36442212365553434]
# Evaluating for signal_strength: 1
# Running  NAM {'landscape_id': 'B1L14RNA1', 'start_id': 'startRNAL14_0', 'signal_strength': 1}
# [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# round: 0, cost: 1, evals: 0.0, top: 0.5437468768175177
# [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# round: 1, cost: 101, evals: 749.0, top: 0.5437468768175177
# [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# round: 2, cost: 201, evals: 1499.0, top: 0.6810566994865414
# [0.33333333333333337, 0.33333333333333337, 0.33333333333333337]
# round: 3, cost: 301, evals: 2242.0, top: 0.6810566994865414
# [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# round: 4, cost: 401, evals: 2711.0, top: 0.6810566994865414
# [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# round: 5, cost: 500, evals: 2810.0, top: 0.6810566994865414
# [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# round: 6, cost: 599, evals: 3040.0, top: 0.7936507645510489
# [0.33333333333333337, 0.33333333333333337, 0.33333333333333337]
# round: 7, cost: 691, evals: 3151.0, top: 0.8540671074772356
# [0.33333333333333337, 0.33333333333333337, 0.33333333333333337]
# round: 8, cost: 760, evals: 3241.0, top: 0.8595594689562722
# [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# round: 9, cost: 824, evals: 3322.0, top: 0.8595594689562722
# [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# Running NN {'landscape_id': 'B1L14RNA1', 'start_id': 'startRNAL14_0'}
# WARNING:tensorflow:From /home/alexander/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /home/alexander/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/alexander/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# round: 0, cost: 1, evals: 0.0, top: 0.5437468768175177
# [0.6095424195903923, 0.31197844286398935, 0.07847913754561825]
# round: 1, cost: 100, evals: 738.0, top: 0.5437468768175177
# [0.24321439374264167, 0.39133950414487845, 0.36544610211247985]
# round: 2, cost: 200, evals: 1433.0, top: 0.8266051429434308
# [0.2697973031074572, 0.3701451227620993, 0.3600575741304434]
# round: 3, cost: 298, evals: 2026.0, top: 0.8266051429434308
# [0.34873315983697006, 0.3466128018442077, 0.3046540383188224]
# round: 4, cost: 392, evals: 2382.0, top: 0.8266051429434308
# [0.33129232669762704, 0.3478852407996902, 0.32082243250268294]
# round: 5, cost: 484, evals: 2568.0, top: 0.9694073270914911
# [0.3140454443528318, 0.3599049884173772, 0.32604956722979106]
# round: 6, cost: 567, evals: 2750.0, top: 0.9694073270914911
# [0.31347624529375023, 0.34380152356430926, 0.34272223114194045]
# round: 7, cost: 651, evals: 2935.0, top: 0.9694073270914911
# [0.3298822824312329, 0.32415144371602955, 0.3459662738527376]
# round: 8, cost: 721, evals: 3103.0, top: 0.9694073270914911
# [0.3331791552512709, 0.3313884586194429, 0.3354323861292862]
# round: 9, cost: 787, evals: 3251.0, top: 0.9694073270914911
# [0.3332504556081826, 0.32392309345719544, 0.34282645093462183]
# Running null  {'landscape_id': 'B1L14RNA1', 'start_id': 'startRNAL14_0'}
# [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# round: 0, cost: 1, evals: 0.0, top: 0.5437468768175177
# [0.7249461048931171, 0.09482331243501481, 0.18023058267186812]
# round: 1, cost: 101, evals: 728.0, top: 0.6151479950813181
# [0.3435884057573456, 0.4360637252256778, 0.2203478690169765]
# round: 2, cost: 201, evals: 1466.0, top: 0.6645795626698909
# [0.7999554087294155, 0.1403877571477802, 0.059656834122804134]
# round: 3, cost: 301, evals: 2206.0, top: 0.6645795626698909
# [0.06493271650464533, 0.06493271650464533, 0.8701345669907093]
# round: 4, cost: 401, evals: 2914.0, top: 0.6645795626698909
# [0.8135815999711079, 0.018325085130596903, 0.16809331489829518]
# round: 5, cost: 501, evals: 3665.0, top: 0.6645795626698909
# [0.037958064167167176, 0.7274348863893936, 0.23460704944343924]
# round: 6, cost: 601, evals: 4386.0, top: 0.6645795626698909
# [0.039240356468878856, 0.4378737529867413, 0.52288589054438]
# round: 7, cost: 701, evals: 5140.0, top: 0.6645795626698909
# [0.06832135146735907, 0.3997563815132471, 0.5319222670193939]
# round: 8, cost: 801, evals: 5863.0, top: 0.6645795626698909
# [0.5417626544397918, 0.33412642103165613, 0.12411092452855202]
# round: 9, cost: 901, evals: 6576.0, top: 0.6645795626698909
# [0.10624605172071906, 0.787507896558562, 0.10624605172071906]
# start seq startRNAL14_1
# Evaluating for signal_strength: 0
# Running  NAM {'landscape_id': 'B1L14RNA1', 'start_id': 'startRNAL14_1', 'signal_strength': 0}
# [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# round: 0, cost: 1, evals: 0.0, top: 0.6508485804029885
# [0.11150423244400419, 0.6700631798205859, 0.21843258773540986]
# round: 1, cost: 101, evals: 730.0, top: 0.6645795626698909
# [0.18390158279588048, 0.4323204502828614, 0.38377796692125804]
# round: 2, cost: 201, evals: 1462.0, top: 0.6645795626698909
# [0.48087391075907443, 0.38731223197531134, 0.13181385726561426]
# round: 3, cost: 301, evals: 2204.0, top: 0.6645795626698909
# [0.4118437767366267, 0.5349869075217457, 0.05316931574162758]
# round: 4, cost: 401, evals: 2933.0, top: 0.6865491133451186
# [0.29986316191984247, 0.18015310704881546, 0.519983731031342]
# round: 5, cost: 501, evals: 3658.0, top: 0.6865491133451186
# [0.2813797453468982, 0.52092726066812, 0.19769299398498186]
# round: 6, cost: 601, evals: 4391.0, top: 0.6865491133451186
# [0.3522324026588921, 0.443803574175993, 0.20396402316511497]
# round: 7, cost: 701, evals: 5118.0, top: 0.6865491133451186
# [0.20196211547508175, 0.5380562008463098, 0.25998168367860847]
# round: 8, cost: 801, evals: 5893.0, top: 0.6865491133451186
# [0.24026470819004977, 0.3330075158992718, 0.4267277759106785]
# round: 9, cost: 901, evals: 6621.0, top: 0.6865491133451186
# [0.16698935137766768, 0.5459608641867977, 0.2870497844355347]
# Evaluating for signal_strength: 0.5
# Running  NAM {'landscape_id': 'B1L14RNA1', 'start_id': 'startRNAL14_1', 'signal_strength': 0.5}
# [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# round: 0, cost: 1, evals: 0.0, top: 0.6508485804029885
# [0.4449729029060749, 0.5217756204253747, 0.03325147666855037]
# round: 1, cost: 101, evals: 727.0, top: 0.6508485804029885
# [0.23742639056365875, 0.06570634400256259, 0.6968672654337787]
# round: 2, cost: 201, evals: 1312.0, top: 0.6508485804029885
# [0.5870684245358314, 0.30784468421850963, 0.10508689124565887]
# round: 3, cost: 300, evals: 1411.0, top: 0.6508485804029885
# [0.906615027514664, 0.07242898374039176, 0.02095598874494422]
# round: 4, cost: 399, evals: 1906.0, top: 0.7002800956120209
# [0.06998724255748358, 0.035963676504325574, 0.8940490809381909]
# round: 5, cost: 499, evals: 2213.0, top: 0.7002800956120209
# [0.06951135738727146, 0.4239792869914467, 0.5065093556212819]
# round: 6, cost: 599, evals: 2447.0, top: 0.7002800956120209
# [0.037962454143276425, 0.5821377529870705, 0.379899792869653]
# round: 7, cost: 698, evals: 2721.0, top: 0.7002800956120209
# [0.6445138217340208, 0.12104995611544085, 0.23443622215053833]
# round: 8, cost: 798, evals: 2973.0, top: 0.7002800956120209
# [0.35156344360285574, 0.3007758820561309, 0.34766067434101333]
# round: 9, cost: 898, evals: 3295.0, top: 0.7002800956120209
# [0.07456894050824651, 0.38867779773724936, 0.5367532617545042]
# Evaluating for signal_strength: 0.9
# Running  NAM {'landscape_id': 'B1L14RNA1', 'start_id': 'startRNAL14_1', 'signal_strength': 0.9}
# [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# round: 0, cost: 1, evals: 0.0, top: 0.6508485804029885
# [0.464301021763237, 0.37930582439819543, 0.15639315383856758]
# round: 1, cost: 101, evals: 738.0, top: 0.6508485804029885
# [0.31350878619064226, 0.2539341799660647, 0.4325570338432929]
# round: 2, cost: 201, evals: 1487.0, top: 0.6508485804029885
# [0.29602482070155206, 0.25470664959716977, 0.44926852970127823]
# round: 3, cost: 301, evals: 2222.0, top: 0.6508485804029885
# [0.2078008305642292, 0.40335773050736295, 0.38884143892840783]
# round: 4, cost: 401, evals: 2977.0, top: 0.6508485804029885
# [0.26698975568170835, 0.39070841017759295, 0.3423018341406988]
# round: 5, cost: 501, evals: 3693.0, top: 0.6508485804029885
# [0.262175808274372, 0.3478381014188404, 0.38998609030678755]
# round: 6, cost: 601, evals: 4420.0, top: 0.6508485804029885
# [0.28962868530673963, 0.2972713653928651, 0.41309994930039523]
# round: 7, cost: 701, evals: 5154.0, top: 0.6508485804029885
# [0.43814840889998613, 0.2392139154923038, 0.32263767560771006]
# round: 8, cost: 801, evals: 5885.0, top: 0.6508485804029885
# [0.2954922482490998, 0.47301513288879204, 0.23149261886210817]
# round: 9, cost: 901, evals: 6600.0, top: 0.6508485804029885
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-54e5c0fcb830> in <module>
#       1 evaluator_dqn=Evaluator(dqn_explorer_prod,landscape_types=LANDSCAPE_TYPES_RNA, path="../simulations/eval/")
# ----> 2 evaluator_dqn.evaluate_for_landscapes(evaluator_dqn.consistency_robustness_independence, num_starts=3)
#
# ~/Documents/FLSD-Sandbox/evaluators/Evaluator.py in evaluate_for_landscapes(self, property_of_interest_evaluator, num_starts)
#     208                       start_seq_id = starting_seq
#     209                       start_seq = landscape["starting_seqs"][starting_seq]
# --> 210                       property_of_interest_evaluator(oracle, start_seq, landscape_id, start_seq_id)
#     211                       starts_per_landscape += 1
#     212                       if starts_per_landscape >= num_starts:
#
# ~/Documents/FLSD-Sandbox/evaluators/Evaluator.py in consistency_robustness_independence(self, oracle, start_seq, landscape_id, start_seq_id)
#     225                                       "signal_strength": ss , \
#     226                                        }
# --> 227                   self.run_on_NAM(oracle,landscape_idents, start_seq, verbose=True)
#     228               landscape_idents={"landscape_id":landscape_id,\
#     229                                       "start_id":start_seq_id}
#
# ~/Documents/FLSD-Sandbox/evaluators/Evaluator.py in run_on_NAM(self, landscape_oracle, NAM_args, start_seq, num_batches, hot_start, verbose, overwrite)
#     156                nam_ensemble_landscape.update_model([start_seq])
#     157             self.explorer.set_model(nam_ensemble_landscape)
# --> 158             self.explorer.run(num_batches, overwrite= overwrite, verbose=verbose)
#     159
#     160
#
# ~/Documents/FLSD-Sandbox/explorers/base_explorer.py in run(self, rounds, overwrite, verbose)
#      75             if verbose:
#      76                print (f'round: {r}, cost: {self.model.cost}, evals: {self.model.evals}, top: {max(self.model.measured_sequences.values())}')
# ---> 77             new_samples = self.propose_samples()
#      78             self.measure_proposals(new_samples)
#      79             if not self.debug:
#
# ~/Documents/FLSD-Sandbox/explorers/dqn_explorer.py in propose_samples(self)
#     186         total_evals = 0
#     187         while (self.model.cost - prev_cost < self.batch_size) and (total_evals < self.batch_size * self.virtual_screen):
# --> 188             new_state_string, reward = self.pick_action()
#     189             samples.add(new_state_string)
#     190             total_evals += 1
#
# ~/Documents/FLSD-Sandbox/explorers/dqn_explorer.py in pick_action(self)
#     164         action, new_state = self.get_action_and_mutant(eps)
#     165         new_state_string = translate_one_hot_to_string(new_state, self.alphabet)
# --> 166         reward = self.model.get_fitness(new_state_string)
#     167         if not new_state_string in self.model.measured_sequences:
#     168             if reward >= self.best_fitness:
#
# ~/Documents/FLSD-Sandbox/models/Noisy_models/Ensemble.py in get_fitness(self, sequence)
#      96               return np.mean(fitnesses)
#      97           else:
# ---> 98               fitnesses = self.get_fitness_distribution(sequence)
#      99               weighted_fitnesses =  [f*w for f,w in zip(fitnesses, self.weighted_r2s)]
#     100               return np.sum(weighted_fitnesses)
#
# ~/Documents/FLSD-Sandbox/models/Noisy_models/Ensemble.py in get_fitness_distribution(self, sequence)
#     103           fitnesses = []
#     104           for model in self.models:
# --> 105               fitnesses.append(model.get_fitness(sequence))
#     106           return fitnesses
#
# ~/Documents/FLSD-Sandbox/models/Noisy_models/Noisy_abstract_model.py in get_fitness(self, sequence)
#     113
#     114         else:
# --> 115             self.model_sequences[sequence] = self._fitness_function(sequence)
#     116             self.evals += 1
#     117             return self.model_sequences[sequence]
#
# ~/Documents/FLSD-Sandbox/models/Noisy_models/Noisy_abstract_model.py in _fitness_function(self, sequence)
#      71     def _fitness_function(self,sequence):
#      72         if self.ss < 1:
# ---> 73             distance, neighbor_seq = self.get_min_distance(sequence)
#      74             signal,noise,alpha = self.add_noise(sequence,distance,neighbor_seq)
#      75             surrogate_fitness = signal * alpha + noise * (1 - alpha)
#
# ~/Documents/FLSD-Sandbox/models/Noisy_models/Noisy_abstract_model.py in get_min_distance(self, sequence)
#      41         closest = None
#      42         for seq in self.measured_sequences:
# ---> 43             dist = editdistance.eval(sequence,seq)
#      44             if dist==1:
#      45                new_dist=1
#
# KeyboardInterrupt:

# %%
evaluator_dqn=Evaluator(dqn_explorer_prod,landscape_types=LANDSCAPE_TYPES_RNA, path="../simulations/eval/")
evaluator_dqn.evaluate_for_landscapes(evaluator_dqn.consistency_robustness_independence, num_starts=3)
evaluator_dqn=Evaluator(dqn_explorer_prod,landscape_types=LANDSCAPE_TYPES_TF, path="../simulations/eval/")
evaluator_dqn.evaluate_for_landscapes(evaluator_dqn.consistency_robustness_independence, num_starts=5)

# %%
evaluator_dqn=Evaluator(dqn_explorer_prod,landscape_types=LANDSCAPE_TYPES_RNA, path="../simulations/eval/")
evaluator_dqn.evaluate_for_landscapes(evaluator_dqn.adaptivity, num_starts=3)
evaluator_dqn=Evaluator(dqn_explorer_prod,landscape_types=LANDSCAPE_TYPES_TF, path="../simulations/eval/")
evaluator_dqn.evaluate_for_landscapes(evaluator_dqn.adaptivity, num_starts=5)

# %%
evaluator_dqn=Evaluator(dqn_explorer_prod,landscape_types=LANDSCAPE_TYPES_RNA, path="../simulations/eval/")
evaluator_dqn.evaluate_for_landscapes(evaluator_dqn.efficiency, num_starts=3)
evaluator_dqn=Evaluator(dqn_explorer_prod,landscape_types=LANDSCAPE_TYPES_TF, path="../simulations/eval/")
evaluator_dqn.evaluate_for_landscapes(evaluator_dqn.efficiency, num_starts=5)
