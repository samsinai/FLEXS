# %%
# !conda install -c bioconda viennarna -y
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.12
#   latest version: 4.8.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.

# %%
import os
import itertools
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import sys
sys.path.append("../")
from models.Ground_truth_oracles.RNA_landscape_models import RNA_landscape_constructor
from models.Ground_truth_oracles.TF_binding_landscape_models import *
import multiprocessing 
print('Number of CPUs', multiprocessing.cpu_count())
# Out:
# Number of CPUs 64

# %%
def is_sequence_a_peak(model, sequence, peak_dict, alphabet="AGTC"):
    if sequence in peak_dict:
        return peak_dict[sequence]
    neighbor=[s for s in sequence]
    sequence_fitness=model.get_fitness(sequence)
    for position in range(len(sequence)):
        for aa in alphabet:
            if aa!=sequence[position]:
               neighbor[position]=aa
               neighbor_string="".join(neighbor)
               if sequence_fitness<model.get_fitness(neighbor_string):
                  peak_dict[sequence] = 0
                  return 0
               elif sequence_fitness>model.get_fitness(neighbor_string):
                  peak_dict[neighbor_string] = 0
               neighbor[position]=sequence[position] # reset 
    peak_dict[sequence] = 1
    return 1

def get_peaks_subset(start_subset, model, alphabet):
    peaks=set()
    peak_dict = {}
    for ind, sub_seq in enumerate(itertools.product(alphabet, repeat=11)):
        seq = start_subset + sub_seq
        if ind % 100000 == 0:
            print('Processed {} sequences and found {} peaks in processing sequences starting with {}'.format(ind, len(peaks), start_subset))
        seq = ''.join(seq)
        if is_sequence_a_peak(model, seq, peak_dict, alphabet):
           peaks.add(seq)
    return peaks

def get_all_peaks(landscape, alphabet='AGTC'):
    # we will be running 4^3 = 64 processes, so each individual function will be running on sequences that start with the same XYZ
    pool = multiprocessing.Pool(64)
    start_subset_seqs = itertools.product(alphabet, repeat=3)
    args = [(subset_seq, landscape, alphabet) for subset_seq in start_subset_seqs]
    all_found_peaks = pool.starmap(get_peaks_subset, args)
    peaks = set()
    for peak_subset in all_found_peaks:
        peaks.update(peak_subset)
    peaks = list(peaks)
    return peaks

if not os.path.isdir('../peaks'):
    os.mkdir('../peaks')

# %%
rna_landscape_constructor_1=RNA_landscape_constructor()
rna_landscape_constructor_1.load_landscapes("../data/RNA_landscapes/RNA_landscape_config.yaml", 
                                      landscapes_to_test = [0])
landscape1 = next(rna_landscape_constructor_1.generate_from_loaded_landscapes())
rna_landscape_constructor_2=RNA_landscape_constructor()
rna_landscape_constructor_2.load_landscapes("../data/RNA_landscapes/RNA_landscape_config.yaml", 
                                      landscapes_to_test = [12])
landscape2 = next(rna_landscape_constructor_2.generate_from_loaded_landscapes())
# Out:
# B1L14RNA1 loaded
# B2L14RNA1+2 loaded

# %%
peaks_1 = get_all_peaks(landscape1["landscape_oracle"], 'UGTC')
pickle.dump(peaks_1, open('../peaks/peaks_B1L14RNA1.pkl'))
# Out:
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'G')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'T')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'G')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'U')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'C')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'U')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'U')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'T')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'T')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'C')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'G')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'U')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'G')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'C')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'T')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'C')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('G', 'U', 'G')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('G', 'U', 'C')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('G', 'U', 'U')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('G', 'U', 'T')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('G', 'G', 'U')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('G', 'G', 'G')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('G', 'G', 'T')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('G', 'G', 'C')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('G', 'T', 'G')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('G', 'T', 'T')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('G', 'T', 'U')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('G', 'T', 'C')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('G', 'C', 'U')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('G', 'C', 'C')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('G', 'C', 'G')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('G', 'C', 'T')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'G')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'C')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'U')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'T')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'T')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'G')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'U')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'C')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'U')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'G')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'T')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'C')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'T')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'G')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'U')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'T')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'U')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'C')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'G')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('C', 'G', 'U')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'C')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('C', 'G', 'T')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('C', 'G', 'G')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('C', 'G', 'C')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'G')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'T')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'C')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('C', 'C', 'U')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('C', 'C', 'G')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'U')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('C', 'C', 'T')
# Processed 0 sequences and found 0 peaks in processing sequences starting with ('C', 'C', 'C')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'C')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'U')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'T')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'U')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'T')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'C')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'C')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'G')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'C')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'U')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'G')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'T')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'U')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'T')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'G')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'U')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'C')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'T')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'U')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'T')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'C')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'G')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'C')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'C')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'C')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'G')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'G')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'U')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'T')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'C')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('C', 'G', 'C')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'G')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'U')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'T')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'G')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'U')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'T')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'G')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('C', 'G', 'U')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('C', 'G', 'T')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('C', 'C', 'U')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'U')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'T')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('C', 'C', 'T')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('G', 'U', 'C')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('C', 'C', 'C')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('G', 'C', 'G')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'C')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'T')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'U')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'G')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'U')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'T')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('G', 'U', 'G')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'C')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('C', 'C', 'G')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('G', 'U', 'U')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('G', 'U', 'T')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('G', 'T', 'C')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'C')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('G', 'T', 'G')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'G')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'C')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'U')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'T')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('G', 'T', 'U')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'G')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('G', 'C', 'U')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'U')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('G', 'T', 'T')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('G', 'C', 'T')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'T')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'G')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'U')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'C')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'T')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'U')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'T')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('G', 'G', 'G')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'C')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('G', 'C', 'C')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'C')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'U')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'G')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'T')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'U')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'T')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'C')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'C')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'G')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'C')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'C')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'U')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('C', 'G', 'G')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'T')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'G')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'C')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('C', 'G', 'C')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'U')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'G')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'T')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'G')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'U')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'T')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'C')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'G')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('C', 'G', 'U')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('G', 'G', 'U')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('C', 'C', 'U')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'C')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('C', 'G', 'T')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'G')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('C', 'C', 'T')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'U')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('G', 'G', 'T')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'T')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'U')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('G', 'C', 'G')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'T')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'U')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'T')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'C')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('G', 'U', 'C')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('C', 'C', 'C')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'U')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'T')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'U')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'T')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'G')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('G', 'U', 'G')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'G')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'U')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'C')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'T')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'U')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'G')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'T')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'C')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'G')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('G', 'U', 'U')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('G', 'U', 'T')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'G')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('C', 'C', 'G')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('G', 'T', 'C')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'C')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'C')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('G', 'T', 'G')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'C')
# Processed 100000 sequences and found 0 peaks in processing sequences starting with ('G', 'G', 'C')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'U')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'C')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'T')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'G')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'C')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'U')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'T')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'U')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'G')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'T')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'T')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'U')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'C')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'U')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'G')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'G')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'T')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('G', 'T', 'U')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('G', 'T', 'T')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('C', 'C', 'U')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'G')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('G', 'C', 'U')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('C', 'G', 'C')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('G', 'C', 'T')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'G')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'U')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('C', 'C', 'T')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'G')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('C', 'G', 'U')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'T')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'U')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'G')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'T')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'C')
# Processed 300000 sequences and found 13 peaks in processing sequences starting with ('G', 'C', 'G')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'U')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('C', 'G', 'T')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'C')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'T')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'U')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'C')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'T')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('G', 'C', 'C')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'U')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'T')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('G', 'G', 'G')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'C')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'G')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'C')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('G', 'U', 'G')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'U')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'U')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'T')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'T')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'C')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('G', 'U', 'C')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'G')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('C', 'C', 'C')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'G')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'C')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'G')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('C', 'G', 'G')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'U')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'T')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'G')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'G')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'G')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'U')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'G')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'U')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'T')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('G', 'T', 'G')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'C')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'T')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'G')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'C')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'U')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'G')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'C')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('G', 'U', 'U')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'T')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('G', 'U', 'T')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'C')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('G', 'T', 'C')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'C')
# Processed 400000 sequences and found 1 peaks in processing sequences starting with ('C', 'G', 'C')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'U')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'T')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'C')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'U')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'C')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('G', 'G', 'U')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'U')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'U')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'T')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'T')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'U')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'T')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'T')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'U')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('C', 'G', 'U')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('C', 'C', 'U')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('C', 'C', 'G')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'T')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('C', 'G', 'T')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'C')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'G')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('G', 'G', 'T')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('C', 'C', 'T')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'G')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'G')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'U')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'C')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'G')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'T')
# Processed 800000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'C')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('G', 'T', 'U')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'G')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('G', 'T', 'T')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'U')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'C')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'G')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'T')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'G')
# Processed 800000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'U')
# Processed 800000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'T')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'C')
# Processed 800000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'U')
# Processed 800000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'T')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'C')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'U')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('G', 'U', 'C')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'T')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'G')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'U')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('G', 'U', 'G')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'C')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('G', 'C', 'U')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'C')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'T')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('G', 'C', 'T')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'U')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('G', 'C', 'C')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'G')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'U')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'T')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'C')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'U')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'C')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'T')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'U')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('G', 'G', 'G')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'T')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'C')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'T')
# Processed 500000 sequences and found 1 peaks in processing sequences starting with ('C', 'G', 'C')
# Processed 400000 sequences and found 14 peaks in processing sequences starting with ('G', 'C', 'G')
# Processed 900000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'C')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'G')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('C', 'G', 'U')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'G')
# Processed 800000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'G')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'U')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'T')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'G')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('C', 'C', 'U')
# Processed 900000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'U')
# Processed 900000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'T')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('C', 'G', 'T')
# Processed 900000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'U')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('C', 'C', 'G')
# Processed 900000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'T')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'C')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('G', 'U', 'U')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('G', 'T', 'C')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('G', 'U', 'T')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'G')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'U')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'C')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('G', 'T', 'G')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('C', 'C', 'C')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'T')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('C', 'C', 'T')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'C')
# Processed 800000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'C')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'G')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('C', 'G', 'G')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'G')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'C')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'C')
# Processed 200000 sequences and found 0 peaks in processing sequences starting with ('G', 'G', 'C')
# Processed 1000000 sequences and found 5 peaks in processing sequences starting with ('U', 'G', 'C')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'U')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'G')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('G', 'G', 'U')
# Processed 900000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'G')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'U')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'T')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'G')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'U')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'T')
# Processed 1000000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'U')
# Processed 1000000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'T')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'U')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'T')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'C')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'T')
# Processed 1000000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'U')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'G')
# Processed 1000000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'T')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'C')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'U')
# Processed 800000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'U')
# Processed 800000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'C')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'C')
# Processed 800000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'T')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'T')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'U')
# Processed 300000 sequences and found 0 peaks in processing sequences starting with ('G', 'G', 'T')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'G')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'T')
# Processed 600000 sequences and found 1 peaks in processing sequences starting with ('C', 'G', 'C')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('G', 'T', 'U')
# Processed 900000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'C')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('G', 'T', 'T')
# Processed 800000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'C')
# Processed 800000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'U')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('G', 'U', 'G')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('G', 'C', 'C')
# Processed 800000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'G')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('C', 'G', 'U')
# Processed 800000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'T')
# Processed 500000 sequences and found 14 peaks in processing sequences starting with ('G', 'C', 'G')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('G', 'U', 'C')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('C', 'C', 'U')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'G')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'C')
# Processed 1100000 sequences and found 7 peaks in processing sequences starting with ('U', 'G', 'C')
# Processed 1000000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'G')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('C', 'G', 'T')
# Processed 800000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'G')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('C', 'C', 'T')
# Processed 1100000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'U')
# Processed 1100000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'T')
# Processed 800000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'C')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'C')
# Processed 800000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'U')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'G')
# Processed 800000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'T')
# Processed 900000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'U')
# Processed 900000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'C')
# Processed 900000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'T')
# Processed 1000000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'C')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'G')
# Processed 1100000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'U')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('C', 'G', 'G')
# Processed 800000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'U')
# Processed 1100000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'T')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('G', 'C', 'U')
# Processed 800000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'T')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'G')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'U')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'U')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('G', 'T', 'G')
# Processed 900000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'C')
# Processed 900000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'U')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('G', 'C', 'T')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'T')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'C')
# Processed 600000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'G')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('T', 'U', 'T')
# Processed 900000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'T')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'C')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('C', 'U', 'G')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('G', 'T', 'C')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'C')
# Processed 800000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'G')
# Processed 1100000 sequences and found 0 peaks in processing sequences starting with ('U', 'G', 'G')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'U')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('G', 'U', 'U')
# Processed 900000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'G')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('G', 'U', 'T')
# Processed 1200000 sequences and found 7 peaks in processing sequences starting with ('U', 'G', 'C')
# Processed 700000 sequences and found 1 peaks in processing sequences starting with ('C', 'G', 'C')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('T', 'T', 'T')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'U')
# Processed 400000 sequences and found 0 peaks in processing sequences starting with ('G', 'G', 'G')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'T')
# Processed 800000 sequences and found 0 peaks in processing sequences starting with ('T', 'C', 'C')
# Processed 900000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'G')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('C', 'G', 'U')
# Processed 1000000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'U')
# Processed 1000000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'C')
# Processed 1000000 sequences and found 0 peaks in processing sequences starting with ('U', 'U', 'T')
# Processed 500000 sequences and found 0 peaks in processing sequences starting with ('G', 'C', 'C')
# Processed 600000 sequences and found 14 peaks in processing sequences starting with ('G', 'C', 'G')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('C', 'T', 'G')
# Processed 600000 sequences and found 8 peaks in processing sequences starting with ('G', 'U', 'G')
# Processed 900000 sequences and found 0 peaks in processing sequences starting with ('T', 'G', 'C')
# Processed 500000 sequences and found 7 peaks in processing sequences starting with ('C', 'C', 'G')
# Processed 700000 sequences and found 0 peaks in processing sequences starting with ('C', 'C', 'U')
# Processed 1100000 sequences and found 0 peaks in processing sequences starting with ('U', 'C', 'C')
# Processed 1000000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'C')
# Processed 1000000 sequences and found 0 peaks in processing sequences starting with ('U', 'T', 'U')

# %%
peaks_2 = get_all_peaks(rna_landscape_constructor_2["landscape_oracle"], 'UGTC')
pickle.dump(peaks_2, open('../peaks/peaks_B2L14RNA1+2.pkl'))
