# %%
import sys
sys.path.append('/usr/local/lib/python3.6/site-packages/')
sys.path.append('../')

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import editdistance
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
from evaluators.Evaluator import Evaluator
from explorers.CbAS_DbAS_explorers_with_mutate_recombine import DbAS_explorer
from utils.model_architectures import Mutate_Recombine_Generator

# %%
# define parameters for the generator (a VAE in this case)
mut_rate = 2
recomb_rate = 0.2
verbose = False

# %%
generator = Mutate_Recombine_Generator(mutation_rate=mut_rate, recombination_rate=recomb_rate)

# %%
# define parameters for the explorer
alphabet = 'UGCA'
Q = 0.8
n_convergence = 10
backfill = True
batch_size = 100
virtual_screen = 20
avg_mutations_per_sequence = 2
path = "./simulations"
debug = False

# %%
dbas_explorer = DbAS_explorer(generator, Q, n_convergence,
                              backfill, batch_size, alphabet, virtual_screen,
                              avg_mutations_per_sequence, path, debug)

# %%
# LANDSCAPE_TYPES ={"RNA": [0,1,12,20,25,31],\
#                   "TF": ['POU3F4_REF_R1','PAX3_G48R_R1','SIX6_REF_R1', 'VAX2_REF_R1', 'VSX1_REF_R1']} #for testing

# %%
LANDSCAPE_TYPES ={"RNA": [0],\
                  "TF": []} #for testing

# %%
evaluator=Evaluator(dbas_explorer, landscape_types=LANDSCAPE_TYPES, path="../simulations/evaluations4/", ML_ensemble=["CNNa","CNNa","RF"])
# Out:
# loading landscapes RNA: [0], TF:[]
# B1L14RNA1 loaded
# 0 TF landscapes loaded.
# loading complete

# %%
evaluator.evaluate_for_landscapes(evaluator.consistency_robustness_independence, num_starts=5)
# Out:
# Running on B1L14RNA1
# start seq startRNAL14_0
# Running  NAM {'landscape_id': 'B1L14RNA1', 'start_id': 'startRNAL14_0', 'signal_strength': 0}
# [0.3333333333333333, 0.3333333333333333, 0.3333333333333333]
# round: 0, cost: 1, evals: 0.0, top: 0.5437468768175177
# Starting a DbAS cycle...
# Initial training set size:  1
# Generating samples...
# Proposed 100 new samples
# Top score in proposed samples:  1.3261329415517953
# New training set size:  101
# Generating samples...
# Proposed 100 new samples
# Top score in proposed samples:  1.7356817659165646
# New training set size:  201
# Generating samples...
# Proposed 100 new samples
# Top score in proposed samples:  1.323662972358641
# New training set size:  301
# Generating samples...
# Proposed 100 new samples
# Top score in proposed samples:  1.2569623921098119
# New training set size:  401
# Generating samples...
# Proposed 100 new samples
# Top score in proposed samples:  1.8038711992804437
# New training set size:  501
# ...
